# %%
# !pip install iso639-lang
# !pip install pycountry
# Out:
# Requirement already satisfied: iso639-lang in c:\users\tonic\appdata\local\programs\python\python310\lib\site-packages (2.0.1)
# Requirement already satisfied: pycountry in c:\users\tonic\appdata\local\programs\python\python310\lib\site-packages (22.3.5)
# Requirement already satisfied: setuptools in c:\users\tonic\appdata\local\programs\python\python310\lib\site-packages (from pycountry) (62.6.0)

# %%
lang = {
    'rw' :'Niger-Congo',
    'ab' :'Northwest Caucasian',
    'mn' :'Mongolic',
    'or' :'Indo-European',
    'lv' :'Indo-European',
    'et' :'Uralic',
    'eu' :'Language isolate', #
    'ca' :'Indo-European',
    'pt' :'Indo-European',
    'br' :'Indo-European',
    'pa' :'Indo-European',
    'ia' :'Conlang', #
    'rm' :'Indo-European',
    'es' :'Indo-European',
    'nl' :'Indo-European',
    'zh' :'Sino-Tibetan', #
    'ro' :'Indo-European',
    'pl' :'Indo-European',
    'it' :'Indo-European',
    'el' :'Indo-European',
    'cy' :'Indo-European',
    'cs' :'Indo-European',
    'ja' :'Japonic',
    'zh' :'Sino-Tibetan', #
    'de' :'Indo-European',
    'vi' :'Austroasiatic',
    'id' :'Austronesian',
    'ky' :'Turkic',
    'tt' :'Turkic',
    'fr' :'Indo-European',
    'cnh' :'Sino-Tibetan',
    'cv' :'Turkic',
    'sv' :'Indo-European',
    'sl' :'Indo-European',
    'ru' :'Indo-European',
    'ta' :'Dravidian',
    'ka' :'Kartvelian',
    'fy' :'Indo-European',
    'mt' :'Afro-Asiatic',
    'rm' :'Indo-European',
    'dv' :'Indo-European',
    'sah' :'Turkic',
    'fa' :'Indo-European',
    'ga' :'Indo-European',
    'en' :'Indo-European',
    'eo' :'Conlang', #
    'uk' :'Indo-European',
    'as' :'Indo-European',
    'ar' :'Afro-Asiatic',
    'tr' :'Turkic'
}

# %%
scripts = {
    'ar' :'Arabic', # 160 Arab
    'ab' :'Cyrillic', # 220 Cyrl 
    'rw' :'Latin', # 215 Latn
    'mn' :'Mongolian', # 145 Mong 
    'or' :'Odia', # 327 Orya 
    'lv' :'Latin',
    'et' :'Latin',
    'eu' :'Latin',
    'ca' :'Latin',
    'pt' :'Latin',
    'br' :'Latin',
    'pa' :'Devanagari',
    'ia' :'Latin',
    'rm' :'Latin',
    'es' :'Latin',
    'nl' :'Latin',
    'zh' :'Han (Simplified variant)', # 501 Hans
    'ro' :'Latin',
    'pl' :'Latin',
    'it' :'Latin',
    'el' :'Greek', # 200 Grek
    'cy' :'Latin',
    'cs' :'Latin',
    'ja' :'Japanese', # 413 Jpan
    'de' :'Latin',
    'vi' :'Latin',
    'id' :'Latin',
    'ky' :'Cyrillic', # 220
    'tt' :'Cyrillic', # 220
    'fr' :'Latin',
    'cnh' :'Latin',
    'cv' :'Cyrillic', # 220
    'sv' :'Latin',
    'sl' :'Latin',
    'ru' :'Cyrillic', # 220
    'ta' :'Tamil', # 346 Taml
    'ka' :'Georgian', # 240 Geor
    'fy' :'Latin',
    'mt' :'Latin',
    'rm' :'Latin',
    'dv' :'Thaana', # 170 Thaa
    'sah' :'Cyrillic', # 220
    'fa' :'Arabic', # 160
    'ga' :'Latin',
    'en' :'Latin',
    'eo' :'Latin',
    'uk' :'Cyrillic', # 220
    'as' :'Assamese', # 325 Bengali (Bangla)
    'ar' :'Arabic', # 160
    'tr' :'Latin',
    'fi' :'Latin',
    'hi' :'Devanagari', # 315 Deva 
    'is' :'Latin',
    'ko' :'Hangul', # 286
    'th' :'Thai' # 352
}

# %%
import csv
import glob
from iso639 import Lang
import pycountry
from langcodes import *
import os

csvsToAnalyze=glob.glob("./../../../data/filtered/corpora/cv/*.csv")
with open("./../../../data/filtered/descriptive_tables/common_voice.csv", 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(["language", "iso_code", "#types", "#tokens", "family", "script"])
    for csvfile in csvsToAnalyze:
        if "phone" not in csvfile: 
            with open(csvfile, newline='',encoding="utf-8") as csvfileOpened:
                reader = csv.reader(csvfileOpened, delimiter=',', quotechar='"')
                next(reader)
                names=csvfile.split("/")[7].split("-")
                isoLanIdentifier=names[0].split("\\")[1]
                isoLan=Lang(isoLanIdentifier).pt1
                if (isoLan==""):
                    isoLan=Lang(isoLanIdentifier).pt3
                dialect=""
                totalReps=0
                diffTokens=0
                for row in reader:
                    totalReps+=int(row[1])
                    diffTokens+=1
                language=pycountry.languages.get(alpha_3=Lang(isoLan).pt3)
                script = scripts[isoLan]
                if "word" not in names[1]:
                    dialect=names[1]
                if((dialect=="HK")|(dialect=="TW")): script = 'Han (Traditional variant)'
                print([language.name,Lang(isoLan).pt3,diffTokens,totalReps,lang[isoLan],script])
                writer.writerow([language.name,Lang(isoLan).pt3,diffTokens,totalReps,lang[isoLan],script])
            os.rename(csvfile,csvfile.split("\\")[0]+"\\"+Lang(isoLan).pt3+"-word.csv")
# Out:
# ['Abkhazian', 'abk', 151, 257, 'Northwest Caucasian', 'Cyrillic']
# ['Arabic', 'ara', 7498, 75885, 'Afro-Asiatic', 'Arabic']
# ['Assamese', 'asm', 1116, 3406, 'Indo-European', 'Assamese']
# ['Breton', 'bre', 4323, 56313, 'Indo-European', 'Latin']
# ['Catalan', 'cat', 79214, 4339449, 'Indo-European', 'Latin']
# ['Czech', 'ces', 16033, 208321, 'Indo-European', 'Latin']
# ['Chuvash', 'chv', 5566, 22363, 'Turkic', 'Cyrillic']
# ['Hakha Chin', 'cnh', 2516, 24117, 'Sino-Tibetan', 'Latin']
# ['Welsh', 'cym', 11489, 726532, 'Indo-European', 'Latin']
# ['German', 'deu', 150363, 5568728, 'Indo-European', 'Latin']
# ['Dhivehi', 'div', 156, 27937, 'Indo-European', 'Thaana']
# ['Modern Greek (1453-)', 'ell', 5835, 52655, 'Indo-European', 'Greek']
# ['English', 'eng', 173523, 13165065, 'Indo-European', 'Latin']
# ['Esperanto', 'epo', 27933, 580737, 'Conlang', 'Latin']
# ['Estonian', 'est', 30136, 157136, 'Uralic', 'Latin']
# ['Basque', 'eus', 24999, 647545, 'Language isolate', 'Latin']
# ['Persian', 'fas', 13241, 2270925, 'Indo-European', 'Arabic']
# ['French', 'fra', 162741, 5013963, 'Indo-European', 'Latin']
# ['Western Frisian', 'fry', 8420, 83230, 'Indo-European', 'Latin']
# ['Irish', 'gle', 2312, 30900, 'Indo-European', 'Latin']
# ['Interlingua (International Auxiliary Language Association)', 'ina', 5553, 44096, 'Conlang', 'Latin']
# ['Indonesian', 'ind', 3818, 62554, 'Austronesian', 'Latin']
# ['Italian', 'ita', 55481, 1052480, 'Indo-European', 'Latin']
# ['Georgian', 'kat', 7946, 20186, 'Kartvelian', 'Georgian']
# ['Kinyarwanda', 'kin', 135329, 2670472, 'Niger-Congo', 'Latin']
# ['Kirghiz', 'kir', 10498, 87002, 'Turkic', 'Cyrillic']
# ['Latvian', 'lav', 7793, 45501, 'Indo-European', 'Latin']
# ['Maltese', 'mlt', 8149, 57765, 'Afro-Asiatic', 'Latin']
# ['Mongolian', 'mon', 14845, 92333, 'Mongolic', 'Mongolian']
# ['Dutch', 'nld', 10667, 414201, 'Indo-European', 'Latin']
# ['Oriya (macrolanguage)', 'ori', 922, 4763, 'Indo-European', 'Odia']
# ['Panjabi', 'pan', 96, 311, 'Indo-European', 'Devanagari']
# ['Polish', 'pol', 25366, 825114, 'Indo-European', 'Latin']
# ['Portuguese', 'por', 13050, 397441, 'Indo-European', 'Latin']
# ['Romansh', 'roh', 9802, 57751, 'Indo-European', 'Latin']
# ['Romanian', 'ron', 6450, 43673, 'Indo-European', 'Latin']
# ['Russian', 'rus', 31922, 829543, 'Indo-European', 'Cyrillic']
# ['Yakut', 'sah', 8042, 31680, 'Turkic', 'Cyrillic']
# ['Slovenian', 'slv', 5995, 37368, 'Indo-European', 'Latin']
# ['Spanish', 'spa', 75618, 2484904, 'Indo-European', 'Latin']
# ['Swedish', 'swe', 4455, 88684, 'Indo-European', 'Latin']
# ['Tamil', 'tam', 1526, 50921, 'Dravidian', 'Tamil']
# ['Tatar', 'tat', 22314, 208719, 'Turkic', 'Cyrillic']
# ['Turkish', 'tur', 8958, 152789, 'Turkic', 'Latin']
# ['Ukrainian', 'ukr', 14400, 166691, 'Indo-European', 'Cyrillic']
# ['Vietnamese', 'vie', 575, 1744, 'Austroasiatic', 'Latin']
