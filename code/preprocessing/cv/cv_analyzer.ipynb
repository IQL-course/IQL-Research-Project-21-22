# %%
# !pip install iso639-lang
# !pip install pycountry
# Out:
# Requirement already satisfied: iso639-lang in e:\programs\python\python37\lib\site-packages (2.1.0)
# WARNING: Ignoring invalid distribution -ip (e:\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\programs\python\python37\lib\site-packages)
# Requirement already satisfied: pycountry in e:\programs\python\python37\lib\site-packages (22.3.5)
# WARNING: Ignoring invalid distribution -ip (e:\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\programs\python\python37\lib\site-packages)
# Requirement already satisfied: setuptools in e:\programs\python\python37\lib\site-packages (from pycountry) (61.2.0)

# %%
lang = {
    'rw' :'Niger-Congo',
    'ab' :'Northwest Caucasian',
    'mn' :'Mongolic',
    'or' :'Indo-European',
    'lv' :'Indo-European',
    'et' :'Uralic',
    'eu' :'Language isolate', #
    'ca' :'Indo-European',
    'pt' :'Indo-European',
    'br' :'Indo-European',
    'pa' :'Indo-European',
    'ia' :'', #
    'rm' :'Indo-European',
    'es' :'Indo-European',
    'nl' :'Indo-European',
    'zh' :'Sino-Tibetan', #
    'ro' :'Indo-European',
    'pl' :'Indo-European',
    'it' :'Indo-European',
    'el' :'Indo-European',
    'cy' :'Indo-European',
    'cs' :'Indo-European',
    'ja' :'Japonic',
    'zh' :'Sino-Tibetan', #
    'de' :'Indo-European',
    'vi' :'Austroasiatic',
    'id' :'Austronesian',
    'ky' :'Turkic',
    'tt' :'Turkic',
    'fr' :'Indo-European',
    'cnh' :'Sino-Tibetan',
    'cv' :'Turkic',
    'sv' :'Indo-European',
    'sl' :'Indo-European',
    'ru' :'Indo-European',
    'ta' :'Dravidian',
    'ka' :'Kartvelian',
    'fy' :'Indo-European',
    'mt' :'Afro-Asiatic',
    'rm' :'Indo-European',
    'dv' :'Indo-European',
    'sah' :'Turkic',
    'fa' :'Indo-European',
    'ga' :'Indo-European',
    'en' :'Indo-European',
    'eo' :'', #
    'uk' :'Indo-European',
    'as' :'Indo-European',
    'ar' :'Afro-Asiatic',
    'tr' :'Turkic'
}

# %%
scripts = {
    'ar' :'Arab', # 160
    'ab' :'Cyrl', # 220 Cyrillic 
    'rw' :'Latn', # 215
    'mn' :'Mong', # 145
    'or' :'Orya', # 327 Odia 
    'lv' :'Latn',
    'et' :'Latn',
    'eu' :'Latn',
    'ca' :'Latn',
    'pt' :'Latn',
    'br' :'Latn',
    'pa' :'Arab',
    'ia' :'Latn',
    'rm' :'Latn',
    'es' :'Latn',
    'nl' :'Latn',
    'zh' :'Hans', # 501 simplified Chinese
    'ro' :'Latn',
    'pl' :'Latn',
    'it' :'Latn',
    'el' :'Grek', # 200 Greek
    'cy' :'Latn',
    'cs' :'Latn',
    'ja' :'Jpan', # 413 Japanese
    'de' :'Latn',
    'vi' :'Latn',
    'id' :'Latn',
    'ky' :'Cyrl', # 220
    'tt' :'Cyrl', # 220
    'fr' :'Latn',
    'cnh' :'Latn',
    'cv' :'Cyrl', # 220
    'sv' :'Latn',
    'sl' :'Latn',
    'ru' :'Cyrl', # 220
    'ta' :'Taml', # 346 Tamil
    'ka' :'Geor', # 240 Georgian
    'fy' :'Latn',
    'mt' :'Latn',
    'rm' :'Latn',
    'dv' :'Thaa', # 170 Thaana
    'sah' :'Cyrl', # 220
    'fa' :'Arab', # 160
    'ga' :'Latn',
    'en' :'Latn',
    'eo' :'Latn',
    'uk' :'Cyrl', # 220
    'as' :'Beng', # 325 Bengali (Bangla)  TODO script of Assamese
    'ar' :'Arab', # 160
    'tr' :'Latn'
}

# %%
import csv
import glob
from iso639 import Lang
import pycountry
from langcodes import *

csvsToAnalyze=glob.glob("./../../../data/cv/*.csv")
with open("./../../../data/descriptive_tables/common_voice.csv", 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(["language", "iso_code", "dialect", "#types", "#tokens", "family", "script"])
    for csvfile in csvsToAnalyze:
        if "phone" not in csvfile: 
            with open(csvfile, newline='',encoding="utf-8") as csvfileOpened:
                reader = csv.reader(csvfileOpened, delimiter=',', quotechar='"')
                next(reader)
                names=csvfile.split("/")[5].split("-")
                isoLan=names[0].split("\\")[1]
                dialect=""
                if "word" not in names[1]:
                    dialect=names[1]
                totalReps=0
                diffTokens=0
                for row in reader:
                    totalReps+=int(row[0])
                    diffTokens+=1
                language=pycountry.languages.get(alpha_3=Lang(isoLan).pt3)
                script = scripts[isoLan]
                if((dialect=="HK")|(dialect=="TW")): script = 'Hant'
                print(isoLan,Lang(isoLan).name,lang[isoLan],script)  #test
                if(dialect!=""): print("----------dialect",dialect) #test
                writer.writerow([language.name,Lang(isoLan).pt3,dialect,diffTokens,totalReps,lang[isoLan],script])
# Out:
# ab Abkhazian Northwest Caucasian Cyrl
# ar Arabic Afro-Asiatic Arab
# as Assamese Indo-European Beng
# br Breton Indo-European Latn
# ca Catalan Indo-European Latn
# cnh Hakha Chin Sino-Tibetan Latn
# cs Czech Indo-European Latn
# cv Chuvash Turkic Cyrl
# cy Welsh Indo-European Latn
# de German Indo-European Latn
# dv Dhivehi Indo-European Thaa
# el Modern Greek (1453-) Indo-European Grek
# en English Indo-European Latn
# eo Esperanto  Latn
# es Spanish Indo-European Latn
# et Estonian Uralic Latn
# eu Basque Language isolate Latn
# fa Persian Indo-European Arab
# fr French Indo-European Latn
# fy Western Frisian Indo-European Latn
# ----------dialect NL
# ga Irish Indo-European Latn
# ----------dialect IE
# ia Interlingua (International Auxiliary Language Association)  Latn
# id Indonesian Austronesian Latn
# it Italian Indo-European Latn
# ja Japanese Japonic Jpan
# ka Georgian Kartvelian Geor
# ky Kirghiz Turkic Cyrl
# lv Latvian Indo-European Latn
# mn Mongolian Mongolic Mong
# mt Maltese Afro-Asiatic Latn
# nl Dutch Indo-European Latn
# or Oriya (macrolanguage) Indo-European Orya
# pa Panjabi Indo-European Arab
# ----------dialect IN
# pl Polish Indo-European Latn
# pt Portuguese Indo-European Latn
# rm Romansh Indo-European Latn
# ----------dialect sursilv
# rm Romansh Indo-European Latn
# ----------dialect vallader
# rm Romansh Indo-European Latn
# ro Romanian Indo-European Latn
# ru Russian Indo-European Cyrl
# rw Kinyarwanda Niger-Congo Latn
# sah Yakut Turkic Cyrl
# sl Slovenian Indo-European Latn
# sv Swedish Indo-European Latn
# ----------dialect SE
# ta Tamil Dravidian Taml
# tr Turkish Turkic Latn
# tt Tatar Turkic Cyrl
# uk Ukrainian Indo-European Cyrl
# vi Vietnamese Austroasiatic Latn
# zh Chinese Sino-Tibetan Hans
# ----------dialect CN
# zh Chinese Sino-Tibetan Hant
# ----------dialect HK
# zh Chinese Sino-Tibetan Hant
# ----------dialect TW
