# %% [markdown]
# # Zipf's law of compression

# %%
from io import open
import numpy as np
import pandas as pd
import re
import os 
from conllu import parse_incr
from collections import Counter
from string import digits, punctuation
from csv import writer
import pycountry

# romanize languages
import pinyin                                                                               # chinese
import pykakasi                                                                             # japanese
kks = pykakasi.kakasi()
from korean_romanizer.romanizer import Romanizer                                            # korean

# %%
# Get PUD languages
my_list = os.listdir('ud-treebanks-v2.9')
pud_langs = [folder[3:-4] for folder in my_list if re.search(r'\bPUD\b', folder)]      # get PUD languages
pud_langs.sort()                                                                       # sort alphabetically

# non latin languages
non_latin_langs = ['Arabic','Chinese','Hindi','Japanese','Korean','Russian','Thai']

# iso codes
langs_dictionary = {}

for language in pud_langs:
    language_item = pycountry.languages.get(name=language)
    langs_dictionary[language] = language_item.alpha_3

langs_df = pd.DataFrame.from_dict(langs_dictionary, orient= "index")
langs_df.to_csv("utils/PUD_languages.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-0c7e65ba9a9d> in <module>
#       1 # Get PUD languages
# ----> 2 my_list = os.listdir('ud-treebanks-v2.9')
#       3 pud_langs = [folder[3:-4] for folder in my_list if re.search(r'\bPUD\b', folder)]      # get PUD languages
#       4 pud_langs.sort()                                                                       # sort alphabetically
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ud-treebanks-v2.9'

# %%
# define filtering function
regex = f'[{digits}{punctuation}“。、・”«»—，）（·》《；：？％』『？」「–„–£…°€’‘¿№＝〜℃ⅲ＆１２２１６／α•／]+'
non_lat_regex = f'[a-zA-Z]+'

def is_valid(language,value):
    # does it contain latin letters while being non latin language?
    if (language in non_latin_langs and re.findall(non_lat_regex, value)):
        return False
    # contains digits or punctuation?
    elif bool(re.findall(regex, value)):
        return False
    elif value == "":
        return False
    
    return True

# %%
# define function to romanize languages (!! not currently used)
def romanize(language,word):
    non_romance_langs = ['Chinese','Japanese','Korean']
    # apply Caesar move!
    if   language == "Chinese":
        return pinyin.get(word, format="strip", delimiter=" ")
    elif language == "Japanese":
        return kks.convert(word)[0]['hepburn']   
    elif language == "Korean":
        return Romanizer(word).romanize() 
    elif not language in non_romance_langs:
        return word

# %%
# # MAIN FUNCTION
# def freq_length_df(language):
#     folder = "UD_"+language+"-PUD"
#     print(folder)
#     [right_file] = [f for f in os.listdir(f'ud-treebanks-v2.9/{folder}') if f.endswith('.conllu')]
#     data_file = open(f'ud-treebanks-v2.9/{folder}/{right_file}', "r", encoding="utf-8")

#     word_counts_raw = Counter()  

#     for sentence in parse_incr(data_file):
#         tokens = [token["form"].lower() for token in sentence]
#         word_counts_raw.update(tokens)

#     word_counts =  {} # will hold word count and length 

#     for word, count in word_counts_raw.items():
#         if is_valid(language, word): 
#             romanized_word = romanize(language, word)     # romanize
#             romanized_word = romanized_word.replace(' ', '')        # replace all white spaces
#             # annotate frequency and length
#             word_counts[romanized_word] = {
#                 'word': word,
#                 'frequency': count,
#                 'length': len(romanized_word)
#             }


#     # save frequency and length 
#     df = pd.DataFrame.from_dict(word_counts, orient='index')
#     print(df.head())
#     df = df.sort_values(by=['frequency'],ascending=False)
#     df.to_csv(f'data/{langs_dictionary[language]}.csv')
#     #df.to_csv(f'data/{langs_dictionary[language]}_pud.txt', index=None, sep=',', mode='a')
#     return df


# MAIN FUNCTION
def freq_length_df(language):
    folder = "UD_"+language+"-PUD"
    print(folder)
    [right_file] = [f for f in os.listdir(f'ud-treebanks-v2.9/{folder}') if f.endswith('.conllu')]
    data_file = open(f'ud-treebanks-v2.9/{folder}/{right_file}', "r", encoding="utf-8")

    word_counts_raw = Counter()  

    for sentence in parse_incr(data_file):
        tokens = [token["form"].lower() for token in sentence]
        word_counts_raw.update(tokens)

    word_counts =  {} # will hold word count and length 

    for word, count in word_counts_raw.items():
        if is_valid(language, word): 
            word = word.replace(' ', '')        # replace all white spaces
            # annotate frequency and length
            word_counts[word] = {
                'word': word,
                'frequency': count,
                'length': len(word)
            }


    # save frequency and length 
    df = pd.DataFrame.from_dict(word_counts, orient='index')
    print(df.head())
    df = df.sort_values(by=['frequency'],ascending=False)
    df.to_csv(f'data/{langs_dictionary[language]}.csv')
    #df.to_csv(f'data/{langs_dictionary[language]}_pud.txt', index=None, sep=',', mode='a')
    return df

# %%
# BUILD DATAFRAMES
[freq_length_df(lang) for lang in pud_langs]
# Out:
# UD_Arabic-PUD
#               word  frequency  length
# كتبت          كتبت          1       4
# كوري          كوري          4       4
# شولمان      شولمان          1       6
# المساعدة  المساعدة          3       8
# الخاصة      الخاصة         26       6
# UD_Chinese-PUD
#     word  frequency  length
# 雖然    雖然          5       2
# 美國    美國         30       2
# 的      的       1362       1
# 許多    許多         16       2
# 數字化  數字化          1       3
# UD_Czech-PUD
#                 word  frequency  length
# v                  v        466       1
# tomto          tomto          3       5
# procesu      procesu          1       7
# předávání  předávání          3       9
# moci            moci          5       4
# UD_English-PUD
#             word  frequency  length
# while      while         13       5
# much        much         12       4
# of            of        620       2
# the          the       1441       3
# digital  digital          3       7
# UD_Finnish-PUD
#                         word  frequency  length
# vaikka                vaikka         11       6
# yhdysvaltojen  yhdysvaltojen          4      13
# siirtyminen      siirtyminen          1      11
# digitaaliseen  digitaaliseen          1      13
# aikaan                aikaan         15       6
# UD_French-PUD
#           word  frequency  length
# alors    alors         11       5
# que        que        203       3
# la          la        747       2
# plus      plus        117       4
# grande  grande         12       6
# UD_German-PUD
#                 word  frequency  length
# ein              ein        126       3
# großteil    großteil          6       8
# des              des        132       3
# digitalen  digitalen          1       9
# übergangs  übergangs          1       9
# UD_Hindi-PUD
#               word  frequency  length
# संयुक्त    संयुक्त          6       7
# राज्य        राज्य         20       5
# अमेरिका    अमेरिका         21       7
# में            में        825       3
# ज्यादातर  ज्यादातर         11       8
# UD_Icelandic-PUD
#                     word  frequency  length
# þótt                þótt         13       4
# mikið              mikið          7       5
# af                    af        104       2
# stafrænu        stafrænu          1       8
# umskiptunum  umskiptunum          1      11
# UD_Indonesian-PUD
#                   word  frequency  length
# meski            meski         16       5
# kebanyakan  kebanyakan          1      10
# transisi      transisi          6       8
# digital        digital          3       7
# yang              yang        541       4
# UD_Italian-PUD
#           word  frequency  length
# mentre  mentre         15       6
# gran      gran         17       4
# parte    parte         46       5
# della    della        185       5
# di          di       1487       2
# UD_Japanese-PUD
#       word  frequency  length
# 米国      米国         18       2
# で        で        585       1
# デジタル  デジタル          3       4
# へ        へ         36       1
# の        の       1753       1
# UD_Korean-PUD
#       word  frequency  length
# 오바마    오바마          1       3
# 대통령    대통령         10       3
# 특별      특별          1       2
# 보좌관은  보좌관은          1       4
# 월요일    월요일          1       3
# UD_Polish-PUD
#                             word  frequency  length
# w                              w        685       1
# przeciwieństwie  przeciwieństwie          1      15
# do                            do        186       2
# przejęcia              przejęcia          2       9
# sfery                      sfery          1       5
# UD_Portuguese-PUD
#           word  frequency  length
# embora  embora          6       6
# uma        uma        209       3
# grande  grande         29       6
# parte    parte         24       5
# da          da        306       2
# UD_Russian-PUD
#                   word  frequency  length
# если              если         17       4
# передача      передача          1       8
# цифровых      цифровых          3       8
# технологий  технологий          4      10
# сегодня        сегодня          6       7
# UD_Spanish-PUD
#                     word  frequency  length
# aunque            aunque          8       6
# no                    no        124       2
# haya                haya          2       4
# precedentes  precedentes          1      11
# para                para        144       4
# UD_Swedish-PUD
#               word  frequency  length
# fast          fast          5       4
# mycket      mycket         16       6
# av              av        369       2
# den            den        263       3
# digitala  digitala          2       8
# UD_Thai-PUD
#                   word  frequency  length
# แม้                แม้         15       3
# ว่า                ว่า        254       3
# การเปลี่ยน  การเปลี่ยน          3      10
# ไป                  ไป        179       2
# ใช้                ใช้         71       3
# UD_Turkish-PUD
#                 word  frequency  length
# özel            özel         12       4
# asistanı    asistanı          1       8
# kori            kori          1       4
# schulman    schulman          1       8
# pazartesi  pazartesi          1       9
# [          word  frequency  length
#  و            و        710       1
#  في          في        652       2
#  من          من        544       2
#  ب            ب        536       1
#  ل            ل        442       1
#  ...        ...        ...     ...
#  ذكية      ذكية          1       4
#  أناساً  أناساً          1       6
#  رأيت      رأيت          1       4
#  ستايل    ستايل          1       5
#  لسلام    لسلام          1       5
#
#  [6602 rows x 3 columns],
#     word  frequency  length
#  的     的       1362       1
#  在     在        415       1
#  了     了        380       1
#  一     一        249       1
#  是     是        215       1
#  ..  ...        ...     ...
#  談     談          1       1
#  死者   死者          1       2
#  橋樑   橋樑          1       2
#  界限   界限          1       2
#  宣言   宣言          1       2
#
#  [4974 rows x 3 columns],
#              word  frequency  length
#  v              v        466       1
#  a              a        466       1
#  se            se        320       2
#  na            na        244       2
#  je            je        174       2
#  ...          ...        ...     ...
#  niklu      niklu          1       5
#  zinku      zinku          1       5
#  olova      olova          1       5
#  manganu  manganu          1       7
#  přítele  přítele          1       7
#
#  [7360 rows x 3 columns],
#                  word  frequency  length
#  the              the       1441       3
#  of                of        620       2
#  in                in        510       2
#  to                to        481       2
#  and              and        456       3
#  ...              ...        ...     ...
#  rastiz        rastiz          1       6
#  rastislav  rastislav          1       9
#  victim        victim          1       6
#  statute      statute          1       7
#  proconsul  proconsul          1       9
#
#  [5082 rows x 3 columns],
#                                  word  frequency  length
#  ja                                ja        431       2
#  on                                on        274       2
#  että                            että        145       4
#  oli                              oli        137       3
#  hän                              hän        114       3
#  ...                              ...        ...     ...
#  pääomasijoitusten  pääomasijoitusten          1      17
#  infrastruktuuria    infrastruktuuria          1      16
#  paransi                      paransi          1       7
#  omansa                        omansa          1       6
#  ystäväksi                  ystäväksi          1       9
#
#  [7076 rows x 3 columns],
#                  word  frequency  length
#  de                de       1607       2
#  le                le        846       2
#  la                la        747       2
#  les              les        712       3
#  à                  à        552       1
#  ...              ...        ...     ...
#  asty            asty          1       4
#  greco          greco          1       5
#  yannis        yannis          1       6
#  smaragdis  smaragdis          1       9
#  déclarait  déclarait          1       9
#
#  [5593 rows x 3 columns],
#                      word  frequency  length
#  die                  die        722       3
#  der                  der        665       3
#  in                    in        529       2
#  und                  und        487       3
#  dem                  dem        410       3
#  ...                  ...        ...     ...
#  malediven      malediven          1       9
#  pazifik          pazifik          1       7
#  line                line          1       4
#  krasnojarsk  krasnojarsk          1      11
#  friedens        friedens          1       8
#
#  [6215 rows x 3 columns],
#                    word  frequency  length
#  के                  के        998       2
#  ।                    ।        982       1
#  में                में        825       3
#  है                  है        533       2
#  की                  की        509       2
#  ...                ...        ...     ...
#  आयरलैंड        आयरलैंड          1       7
#  बर्गेरॉन      बर्गेरॉन          1       8
#  स्वीकृत        स्वीकृत          1       7
#  मूलतः            मूलतः          1       5
#  प्रोकाउंसल  प्रोकाउंसल          1      10
#
#  [4895 rows x 3 columns],
#                              word  frequency  length
#  í                              í        629       1
#  að                            að        570       2
#  og                            og        554       2
#  á                              á        456       1
#  sem                          sem        417       3
#  ...                          ...        ...     ...
#  einkafyrirtækja  einkafyrirtækja          1      15
#  sígarettna            sígarettna          1      10
#  trúarskoðana        trúarskoðana          1      12
#  tjáningu                tjáningu          1       8
#  friðarins              friðarins          1       9
#
#  [6175 rows x 3 columns],
#                  word  frequency  length
#  yang            yang        541       4
#  dan              dan        447       3
#  di                di        422       2
#  nya              nya        381       3
#  untuk          untuk        221       5
#  ...              ...        ...     ...
#  contohnya  contohnya          1       9
#  line            line          1       4
#  maladewa    maladewa          1       8
#  granite      granite          1       7
#  prokonsul  prokonsul          1       9
#
#  [4596 rows x 3 columns],
#                        word  frequency  length
#  di                      di       1487       2
#  il                      il        970       2
#  la                      la        791       2
#  in                      in        605       2
#  a                        a        545       1
#  ...                    ...        ...     ...
#  possedimento  possedimento          1      12
#  provinciali    provinciali          1      11
#  salì                  salì          1       4
#  tonnellate      tonnellate          1      10
#  proconsole      proconsole          1      10
#
#  [5944 rows x 3 columns],
#        word  frequency  length
#  の        の       1753       1
#  に        に       1162       1
#  は        は       1157       1
#  た        た        918       1
#  を        を        851       1
#  ...    ...        ...     ...
#  軽減      軽減          1       2
#  侵食      侵食          1       2
#  塩類      塩類          1       2
#  圧縮      圧縮          1       2
#  読み上げ  読み上げ          1       4
#
#  [4863 rows x 3 columns],
#          word  frequency  length
#  인          인        150       1
#  년          년        140       1
#  그          그        131       1
#  수          수        123       1
#  는          는         94       1
#  ...      ...        ...     ...
#  게임을      게임을          1       3
#  사내에      사내에          1       3
#  부각시켰다  부각시켰다          1       5
#  욕구를      욕구를          1       3
#  선언한      선언한          1       3
#
#  [7813 rows x 3 columns],
#                                  word  frequency  length
#  w                                  w        685       1
#  i                                  i        353       1
#  z                                  z        265       1
#  na                                na        264       2
#  się                              się        262       3
#  ...                              ...        ...     ...
#  przeplatającą          przeplatającą          1      13
#  śródziemnomorskie  śródziemnomorskie          1      17
#  cywilizacje              cywilizacje          1      11
#  geologii                    geologii          1       8
#  przyjaciel                przyjaciel          1      10
#
#  [7329 rows x 3 columns],
#                      word  frequency  length
#  de                    de       1754       2
#  a                      a       1381       1
#  o                      o       1140       1
#  em                    em        774       2
#  e                      e        455       1
#  ...                  ...        ...     ...
#  alianças        alianças          1       8
#  cruciais        cruciais          1       8
#  controlavam  controlavam          1      11
#  estreitos      estreitos          1       9
#  declaração    declaração          1      10
#
#  [5678 rows x 3 columns],
#                        word  frequency  length
#  в                        в        753       1
#  и                        и        477       1
#  на                      на        257       2
#  что                    что        159       3
#  с                        с        156       1
#  ...                    ...        ...     ...
#  звеном              звеном          1       6
#  связующим        связующим          1       9
#  уткнувшихся    уткнувшихся          1      11
#  видела              видела          1       6
#  провозглашал  провозглашал          1      12
#
#  [7156 rows x 3 columns],
#                    word  frequency  length
#  de                  de       1730       2
#  el                  el       1102       2
#  la                  la        795       2
#  en                  en        691       2
#  a                    a        551       1
#  ...                ...        ...     ...
#  monegasco    monegasco          1       9
#  ofreciendo  ofreciendo          1      10
#  limitada      limitada          1       8
#  mónaco          mónaco          1       6
#  declaraba    declaraba          1       9
#
#  [5765 rows x 3 columns],
#                        word  frequency  length
#  i                        i        483       1
#  och                    och        477       3
#  att                    att        452       3
#  som                    som        372       3
#  av                      av        369       2
#  ...                    ...        ...     ...
#  maldiverna      maldiverna          1      10
#  oceanen            oceanen          1       7
#  granitöar        granitöar          1       9
#  seychellerna  seychellerna          1      12
#  fredens            fredens          1       7
#
#  [5842 rows x 3 columns],
#                                word  frequency  length
#  ที่                            ที่        753       3
#  ใน                              ใน        691       2
#  ของ                            ของ        492       3
#  และ                            และ        411       3
#  เป็น                          เป็น        365       4
#  ...                            ...        ...     ...
#  แคบ                            แคบ          1       3
#  ไซเธีย                      ไซเธีย          1       6
#  คริสตศักราช            คริสตศักราช          1      11
#  บาฮากาลิฟอร์เนีย  บาฮากาลิฟอร์เนีย          1      16
#  มิตร                          มิตร          1       4
#
#  [3783 rows x 3 columns],
#                          word  frequency  length
#  bir                      bir        431       3
#  ve                        ve        425       2
#  ki                        ki        197       2
#  bu                        bu        158       2
#  için                    için        120       4
#  ...                      ...        ...     ...
#  maçlarda            maçlarda          1       8
#  zorladığı          zorladığı          1       9
#  dengelediği      dengelediği          1      11
#  bazılarını        bazılarını          1      10
#  yayınlamıştır  yayınlamıştır          1      13
#
#  [6793 rows x 3 columns]]

# %%
# save alphabet size

def countDis(str):
    # Stores all frequencies
    freq = Counter(str)
    # Return the size of the freq dictionary
    return len(freq)

alphabet_dict = {}
for lang in pud_langs:
    df = pd.read_csv(f'data/{lang}.csv')
    str = df['roman_word'].str.cat()
    alphabet_dict[lang] = countDis(str)
df = pd.DataFrame.from_dict(alphabet_dict, orient = 'index', columns=["ab_size"])
df.to_csv("utils/ab_sizes.csv")

# %%
# count empty lemma instances and check for which languages more than 30% is missing or less than 2000 remain.

empty_lemma_dict = {}

for language in pud_langs:
    folder = "UD_"+language+"-PUD"
    [right_file] = [f for f in os.listdir(f'ud-treebanks-v2.9/{folder}') if f.endswith('.conllu')]
    data_file = open(f'ud-treebanks-v2.9/{folder}/{right_file}', "r", encoding="utf-8")

    lemma_counter = Counter()

    for sentence in parse_incr(data_file):
        tokens = [ token['lemma'] for token in sentence if (is_valid(language,token['lemma']) or token['lemma'] == "_")] 
        lemma_counter.update(tokens)   


    share_empty = lemma_counter['_']/sum(lemma_counter.values())
    empty_lemma_dict[language] = {
        "_": round(share_empty,3),
        "tot_lemmas": len(lemma_counter)
    }


removed_lang_list = []
for key, values in dict(empty_lemma_dict).items():
    if (values["_"] >= 0.3 or values["tot_lemmas"] <= 2000):
        removed_lang_list.append(key)
        empty_lemma_dict.pop(key)

print(empty_lemma_dict)
print(removed_lang_list)
# Out:
# {'Czech': {'_': 0.004, 'tot_lemmas': 5090}, 'English': {'_': 0.0, 'tot_lemmas': 4439}, 'Finnish': {'_': 0.001, 'tot_lemmas': 3763}, 'French': {'_': 0.027, 'tot_lemmas': 4302}, 'German': {'_': 0.018, 'tot_lemmas': 5123}, 'Icelandic': {'_': 0.0, 'tot_lemmas': 4468}, 'Indonesian': {'_': 0.024, 'tot_lemmas': 3464}, 'Italian': {'_': 0.069, 'tot_lemmas': 4542}, 'Japanese': {'_': 0.0, 'tot_lemmas': 4636}, 'Polish': {'_': 0.003, 'tot_lemmas': 4789}, 'Portuguese': {'_': 0.269, 'tot_lemmas': 3766}, 'Russian': {'_': 0.0, 'tot_lemmas': 4644}, 'Swedish': {'_': 0.0, 'tot_lemmas': 4708}, 'Turkish': {'_': 0.054, 'tot_lemmas': 4340}}
# ['Arabic', 'Chinese', 'Hindi', 'Korean', 'Spanish', 'Thai']
