# %%
import glob
import csv
import numpy as np
from cihai.core import Cihai
import string

hiraganaKatakanaToStrokes={
    "ぁ":3,
    "あ":3,
    "ぃ":2,
    "い":2,
    "ぅ":2,
    "う":2,
    "ぇ":2,
    "え":2,
    "ぉ":3,
    "お":3,
    "か":3,
    "が":5,
    "き":3,
    "ぎ":5,
    "く": 1,
    "ぐ":3,
    "け":3,
    "げ":5,
    "こ":2,
    "ご":4,
    "さ":2,
    "ざ":4,
    "し":1,
    "じ":3,
    "す":2,
    "ず":4,
    "せ":3,
    "ぜ":5,
    "そ":1,
    "ぞ":3,
    "た":4,
    "だ":6,
    "ち":2,
    "ぢ":4,
    "っ":1,
    "つ":1,
    "づ":3,
    "て":1,
    "で":3,
    "と":2,
    "ど":4,
    "な":4,
    "に":3,
    "ぬ":2,
    "ね":2,
    "の":1,
    "は":3,
    "ば":5,
    "ぱ":4,
    "ひ":1,
    "び":3,
    "ぴ":2,
    "ふ":4,
    "ぶ":6,
    "ぷ":5,
    "へ":1,
    "べ":3,
    "ぺ":2,
    "ほ":4,
    "ぼ":6,
    "ぽ":5,
    "ま":3,
    "み":1,
    "む":3,
    "め":2,
    "も":3,
    "ゃ":3,
    "や":3,
    "ゅ":2,
    "ゆ":2,
    "ょ":2,
    "よ":2,
    "ら":2,
    "り":2,
    "る":1,
    "れ":2,
    "ろ":1,
    "ゎ":2,
    "わ":2,
    "ゐ":1,
    "ゑ":1,
    "を":3,
    "ん":1,
    "ゔ":3,
    "ゕ":3,
    "ゖ":3,
    "ァ":2,
    "ア":2,
    "ィ":2,
    "イ":2,
    "ゥ":3,
    "ウ":3,
    "ェ":3,
    "エ":3,
    "ォ":3,
    "オ":3,
    "カ":2,
    "ガ":4,
    "キ":3,
    "ギ":5,
    "ク":2,
    "グ":4,
    "ケ":3,
    "ゲ":5,
    "コ":2,
    "ゴ":4,
    "サ":3,
    "ザ":5,
    "シ":3,
    "ジ":5,
    "ス":2,
    "ズ":4,
    "セ":2,
    "ゼ":4,
    "ソ":2,
    "ゾ":4,
    "タ":3,
    "ダ":5,
    "チ":3,
    "ヂ":5,
    "ッ":3,
    "ツ":3,
    "ヅ":5,
    "テ":3,
    "デ":5,
    "ト":2,
    "ド":4,
    "ナ":2,
    "ニ":2,
    "ヌ":3,
    "ネ":4,
    "ノ":1,
    "ハ":2,
    "バ":4,
    "パ":3,
    "ヒ":2,
    "ビ":4,
    "ピ":3,
    "フ":1,
    "ブ":3,
    "プ":2,
    "ヘ":1,
    "ベ":3,
    "ペ":2,
    "ホ":4,
    "ボ":6,
    "ポ":5,
    "マ":2,
    "ミ":3,
    "ム":2,
    "メ":2,
    "モ":3,
    "ャ":2,
    "ヤ":2,
    "ュ":2,
    "ユ":2,
    "ョ":3,
    "ヨ":3,
    "ラ":2,
    "リ":2,
    "ル":2,
    "レ":1,
    "ロ":3,
    "ヮ":2,
    "ワ":2,
    "ヲ":3,
    "ン":2,
    "ヴ":5,
    "ヵ":2,
    "ヶ":3,
    "ヷ":4,
    "ヺ":5,
    "々":3,
    "ー":1
    #"＝":2,
    #"〜":1,
    #"℃":2,
    #"ⅲ":6

}
    
    
c = Cihai()
if not c.unihan.is_bootstrapped:  # download and install Unihan to db
    c.unihan.bootstrap()
    
transTable="＝〜℃ⅲ＆１２２１６／α•／"

        
with open('./../pud_data/jpn_pud.csv', newline='',encoding="utf-8") as csvfile:
    with open("./../pud_data/jpn_pud_strokes.csv", 'w', encoding='UTF8', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(["","word","frequency","length"])
        
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='"')
        for row in spamreader:
            word=row[0]
            word = ''.join(i for i in word if i not in transTable)
            if len(word)>0:
                strokeSum=0
                for char in word:
                    if char in hiraganaKatakanaToStrokes:
                        strokeSum+=hiraganaKatakanaToStrokes[char]
                    else:
                        query = c.unihan.lookup_char(char)
                        glyph = query.first()
                        if glyph!=None:
                            strokeSum+=int(glyph.kTotalStrokes)
                        else:
                            print(word)
                writer.writerow([word,word,row[2],strokeSum])
# Out:
# の
# に
# は
# た
# を
# が
# て
# と
# で
# し
# こと
# いる
# ある
# さ
# 年
# れ
# な
# する
# い
# も
# 彼
# 的
# ない
# から
# その
# この
# か
# 人
# 者
# や
# だ
# それ
# ます
# ため
# まし
# 月
# よう
# より
# ら
# なっ
# あり
# これ
# れる
# 私
# あっ
# 彼女
# まで
# 日
# なる
# 後
# つ
# しかし
# また
# られ
# なかっ
# もの
# 多く
# へ
# いう
# 性
# たち
# 前
# 中
# 間
# つい
# できる
# 海
# 必要
# 可能
# 地域
# なく
# でき
# よる
# 家
# ず
# 一
# だろう
# ば
# など
# 映画
# 州
# 世界
# さらに
# 時
# 人々
# 都市
# 歴史
# 政府
# 述べ
# 地
# だっ
# 言っ
# 化
# 新しい
# 英国
# 何
# 大
# です
# 考え
# 支配
# 戦争
# せ
# 他
# 第
# 対する
# おり
# 最も
# 代
# 万
# 影響
# 約
# 対し
# 達
# なり
# 投資
# 国
# 受け
# 米国
# よっ
# 使用
# 中国
# 数
# 投票
# 大統領
# 以上
# 発生
# おい
# 不
# 世紀
# 世
# なら
# 大きな
# せる
# だけ
# 党
# 今
# 川
# 氏
# 成長
# 関係
# 研究
# 語
# 高い
# 企業
# 次
# 知ら
# ほとんど
# 上
# フランス
# アメリカ
# 時代
# 問題
# および
# 調査
# 選挙
# 見
# ヨーロッパ
# 国家
# ローマ
# 最初
# 一部
# 自分
# 場合
# 非常
# 経済
# 紀元
# 警察
# 時間
# スペイン
# 一方
# そこ
# そして
# 共和
# 現在
# ポンド
# 所
# 語っ
# おけ
# る
# 度
# 目的
# システム
# すべて
# オーストラリア
# 労働
# 行動
# 計画
# 軍
# 年間
# 保護
# 始め
# ギリシャ
# 地区
# 歳
# 増加
# 学校
# 様々
# トランプ
# べき
# 際
# ロシア
# 設立
# ところ
# 完全
# 戻っ
# ん
# 力
# 本
# 会
# 最高
# 名前
# 自身
# 持っ
# 結果
# 最終
# 期間
# ドル
# 誰
# どう
# 院
# 系
# 重要
# 政治
# 同じ
# 利用
# 南
# き
# 事件
# でし
# 気候
# 法律
# 市
# 建設
# ませ
# 含ま
# ほど
# 地中
# 女性
# 島
# 提供
# 最近
# 宣言
# 植民
# 体
# 得
# 自由
# 多数
# ドイツ
# 監督
# ながら
# 作品
# レベル
# 億
# 下
# 場
# 部
# とっ
# なけれ
# 平均
# 初めて
# 方法
# 独立
# しか
# 帝国
# 報告
# 全て
# 点
# ユーロ
# 特に
# 技術
# 成功
# 最後
# 男性
# しれ
# 同
# 頃
# 開始
# 移動
# られる
# かけ
# データ
# イタリア
# インド
# 理由
# 実際
# 意味
# 大陸
# 発表
# 情報
# 水
# 移行
# 開発
# 民族
# 地方
# 決定
# 機
# 小さな
# 人口
# 二
# 教会
# 線
# 新た
# 分
# 持つ
# 関する
# 勝利
# 教
# 与え
# 教育
# 明らか
# 人間
# 貿易
# 理解
# 契約
# 修道
# エリア
# たい
# 主義
# 王国
# いく
# 航空
# 革命
# 北部
# 見る
# 条約
# 音楽
# 天皇
# 先住
# 破壊
# アルバム
# とも
# 地球
# アフリカ
# 裁判
# 写真
# すぐ
# 境界
# 協定
# 土地
# 状態
# イギリス
# 変化
# エジプト
# 旧
# 活動
# 北京
# 市場
# 妻
# のみ
# 公
# 上昇
# 素晴らしい
# 要求
# カリブ
# 説明
# 関し
# 香港
# しよう
# ゲーム
# 種
# 役
# 子供
# 常
# 社会
# 代表
# 自然
# 行わ
# 会社
# 大学
# 適切
# 現代
# 位置
# 暮らし
# 公開
# 最大
# 示し
# 役割
# 使う
# 発電
# 国境
# 信じ
# 文明
# 機能
# 予定
# 制限
# 費用
# 一人
# まだ
# 自治
# 主に
# かかわら
# 伝統
# 認め
# 金
# パリ
# 議論
# ポロニウム
# 戦い
# 家族
# 人生
# 平和
# 鉄
# 地下
# 量
# 期
# 思わ
# 学
# 始まっ
# 予測
# 長
# 最新
# 得る
# 名
# 山脈
# 続く
# 向け
# 再び
# 場所
# 冬
# オスマン
# 含む
# あろう
# 大半
# 文化
# アルバニア
# 責任
# クリントン
# 既に
# 国際
# 内
# お
# 書
# 警告
# 専門
# とき
# 資金
# 獲得
# 物
# 理論
# 連邦
# 統治
# 当時
# 王
# 少なく
# 形成
# 一般
# 官
# フォン
# 状況
# 批判
# 科学
# 発見
# 銀行
# 率
# 部分
# 出版
# 方
# アジア
# ロンドン
# 質問
# 継続
# マケドニア
# 深い
# どこ
# 決め
# 横断
# 面
# 古代
# 文学
# 友人
# 直接
# 言葉
# 宗教
# イスラム
# 構成
# 民主
# 変更
# 評価
# 敵
# 皇帝
# 二人
# 権
# ドナルド
# 中心
# 組織
# 曲
# 砂漠
# 近く
# 占め
# メキシコ
# 元
# 動物
# 軍隊
# 娘
# 実現
# 洋
# 口座
# トップ
# 芸術
# ヶ月
# 植物
# 諸国
# 投稿
# 安全
# 征服
# 明確
# あなた
# 独自
# トルコ
# 朝
# キャリア
# 不可欠
# 腫瘍
# いっ
# ニュース
# 賞
# 思う
# 受賞
# くる
# 候補
# そう
# 別
# あまり
# 週間
# 連合
# ロナ
# 代わり
# 適用
# 以来
# もっと
# 以前
# ツール
# 行っ
# 目
# たり
# 許可
# 起き
# 当たり
# 低い
# 試合
# こう
# 国王
# インターネット
# 政権
# 車
# 頻繁
# アクセス
# ケース
# メディア
# 船
# もたらす
# 現れ
# セット
# 国民
# 領土
# 半ば
# 結婚
# 使わ
# 混乱
# 省
# 軍事
# すでに
# 与える
# デンマーク
# 事実
# どの
# よれ
# 言語
# 過去
# モデル
# 色
# 支持
# 続け
# 協会
# 書い
# 清朝
# 品
# 員
# 入学
# モラビア
# ブラント
# 目標
# ここ
# 出し
# ディズニー
# 規模
# 破産
# 票
# 傾向
# やっ
# 数多く
# 当局
# 法
# 支出
# オリンピック
# 関連
# 聖
# 担当
# 生じ
# 古い
# 対立
# 集団
# 到着
# 一緒
# 生き
# 特徴
# 生活
# 物語
# 東
# 販売
# 導入
# 話
# アルプス
# 付け
# キリスト
# 続ける
# 戻る
# 来
# 原因
# 存在
# モンゴル
# 法的
# 紛争
# 乾燥
# 立ち
# 通常
# 進め
# インタビュー
# おら
# 顧客
# 消費
# ほぼ
# オブ
# 政党
# 作成
# 個人
# 範囲
# 議会
# 通り
# 生息
# 粒子
# 町
# タイ
# 簡単
# 産業
# 不足
# 声
# 経験
# 直面
# 女の子
# 文字
# 住ん
# カナダ
# 作業
# 共同
# ワシントン
# 巨大
# 業界
# カメルーン
# 手紙
# どちら
# パターン
# 地帯
# 結局
# 付近
# 男
# 戦闘
# 夏
# 事態
# 将軍
# 撤退
# オープン
# 強制
# 広
# 提案
# ダネヴェルク
# しばしば
# エージェント
# 動産
# オンタリオ
# 作家
# 主張
# 当社
# 使っ
# レース
# ライト
# 進ん
# 管理
# ケシャ
# 準備
# 殺人
# 心
# 削減
# 宇宙
# 多い
# 少し
# うち
# 領
# ビデオ
# 時期
# 仕事
# 年号
# 作曲
# 日本
# 半島
# 生まれ
# アケメネス
# 部隊
# 沿岸
# レコード
# 用
# 手
# いい
# たく
# それぞれ
# 諸島
# 呼ば
# 向かっ
# 山
# 行う
# 建築
# 我々
# 価値
# 移民
# 人気
# スマート
# ファラオ
# 正確
# 高
# 回復
# 表
# 学生
# オランダ
# もちろん
# 残り
# 希望
# 実施
# メール
# リチャード
# 電子
# 敗北
# 知っ
# 完成
# 全体
# スキル
# 主演
# たら
# オーストリア
# ラファティ
# わけ
# 出身
# ライン
# ユダヤ
# 主要
# 展示
# 確信
# 反乱
# 確保
# 注目
# ウィンストン
# 正当
# 電話
# 防衛
# どれ
# 若い
# ショー
# 機会
# 共演
# なぜ
# 残っ
# ノース
# 大戦
# 関心
# 言う
# 解放
# 死ん
# 聴衆
# 合法
# 降伏
# 分析
# 位
# 流れ
# 初め
# 北
# 権力
# 訪問
# 枚
# 及ぼす
# 厳しい
# 発展
# 旅行
# ジョン
# 信頼
# サービス
# 撮影
# 過ごし
# 働い
# 十分
# エピソード
# ユーザー
# 国内
# 医療
# 製品
# 示唆
# 職場
# 言わ
# 資本
# 民
# ディーゼル
# 事業
# 良い
# シリーズ
# 財政
# かつて
# むしろ
# 世論
# デジタル
# 汚染
# 評判
# 判決
# 優先
# 隊
# 減少
# 農地
# 不在
# パプアニューギニア
# 監視
# 渡り
# テレビ
# カップ
# クリストファー
# 選手
# 埋葬
# ランドマーク
# 数字
# 認識
# 行い
# 共
# 面積
# 推定
# 止める
# 最良
# もはや
# 本当
# 勢力
# 表現
# もたらさ
# イングランド
# 河川
# 春
# いれ
# スイス
# 探検
# 驚き
# 風
# 変える
# 語源
# 広がっ
# 外
# やり
# いつ
# ターゲット
# 作る
# 主
# 自国
# プレート
# 周り
# 後者
# 受け入れ
# トラキア
# 圧力
# 徒
# おそらく
# 改宗
# 通じ
# バルカン
# 番組
# アテネ
# 以外
# 精神
# 夢
# 南部
# 平行
# 誌
# 抗議
# 制度
# 低地
# す
# 判断
# 始まる
# アイスランド
# 後年
# 値
# 取っ
# 拡大
# 族
# フィンランド
# 予想
# 関税
# 回
# 分類
# 法案
# カード
# 協議
# 昨年
# 注意
# サハラ
# ずっと
# 似
# 付け加え
# スタイル
# 深く
# 実行
# 健康
# 大きく
# 進軍
# 区
# マーガレット
# デ
# 唯一
# 開催
# 港
# 闘争
# パレード
# 過ぎ
# 伝え
# ブリスベン
# 物質
# ゴルフ
# 前線
# 少ない
# 及び
# 中華
# 衝撃
# 公式
# 太平
# 例
# エネルギー
# 組合
# 支援
# 士
# 選出
# はじめ
# 人種
# 誕生
# 強い
# 合理
# 学者
# 古典
# なし
# 残し
# 越え
# 含ん
# 湖
# 相当
# 公園
# 空気
# 非
# 自ら
# 市内
# キプリング
# アカデミー
# キュリー
# 内戦
# 代理
# 首都
# 祖母
# 保証
# ポール
# 様子
#
# カトリック
# 上回る
# 安定
# 導く
# 選ん
# 三島
# 同盟
# スコットランド
# 有名
# 当初
# 明白
# 手段
# 多様
# マーケット
# いずれ
# アンデス
# 名誉
# 助け
# 派遣
# 総
# 答え
# 今年
# 大使
# 上手く
# 拒否
# 世代
# カロライナ
# 中央
# 共有
# 器
# 病院
# 強調
# わずか
# 短
# 未
# テーマ
# 根本
# 建物
# 反対
# 区域
# 列強
# 旅
# 見つける
# 避妊
# マヤ
# スターリン
# すぎ
# 製作
# パイロット
# 晩年
# 各
# ブランド
# レビュー
# ヒッチコック
# 送信
# 排出
# 炭素
# 引き起こす
# リリース
# 登場
# イベント
# 着陸
# メッセージ
# プリンセス
# しまっ
# ジャスミン
# コース
# 伯爵
# 機関
# 意図
# 民間
# 価格
# 今週
# オスカー
# かなり
# コロンブス
# 依存
# 課す
# 訓練
# 食料
# 作詞
# アルファベット
# 収集
# コメント
# 能力
# 外国
# ほんの
# 同様
# ヒット
# 戦
# 送っ
# 戦後
# アヘン
# 卿
# 海岸
# 貢献
# 欠け
# 締結
# 出演
# 選択
# 環境
# レーダー
# 海外
# 業
# 運河
# 火曜
# 資料
# 攻撃
# 離れ
# ヘロデ
# 日付
# 初頭
# 特定
# 長官
# 推測
# ボグド
# 招待
# ザ
# 終了
# ハーン
# 雇用
# 部門
# 給
# 業績
# かかる
# にて
# 期待
# トトメス
# 特別
# 以降
# 首相
# 国々
# ヘンリー
# 条件
# 無効
# 促進
# 党内
# 指摘
# 立つ
# 積極
# 圏
# 競争
# テクノロジー
# 全国
# 命
# 宣伝
# 学習
# 指揮
# 気温
# 探し
# 類似
# 改革
# 所有
# 内容
# 協力
# 構造
# 率い
# 確立
# カエサル
# 文書
# 占領
# 廃墟
# 登録
# サンタ
# ジョージ
# 設計
# 率いる
# 解体
# 急進
# 姿勢
# 観点
# 機密
# ソフト
# 行為
# 効果
# 弟
# 楽曲
# 肢
# チャンピオン
# ジャティング
# ラブーフ
# リンク
# 密接
# 件
# グランド
# リスト
# リーダー
# 父親
# デザイナー
# 出
# バンド
# 友好
# 躊躇
# トラック
# ストリート
# 阻害
# 極端
# パフォーマンス
# 読む
# 高等
# マーティン
# 廃止
# ナポレオン
# 受ける
# スタジオ
# 欧州
# 回避
# 債
# 許さ
# フィクション
# 試み
# 取り組み
# 経営
# 障害
# 見つけ
# 進む
# 土曜
# ラビング
# エディンバラ
# 顕著
# 妥協
# ポイント
# ミュージカル
# 精巧
# 市民
# 像
# ポーランド
# 体制
# 出馬
# 死刑
# ラテンアメリカ
# 人物
# フロリダ
# 数十
# 住民
# 優勢
# アーティスト
# プレイス
# 競馬
# 界
# ジム
# 織物
# 頭
# アイルランド
# タラ
# 迎え
# ゲイヤー
# 報道
# 入り
# ケルト
# プロジェクト
# 入植
# 終え
# 兄弟
# こそ
# 表面
# 広大
# 調達
# アンディ
# 間違い
# ファンド
# 裁定
# 恩恵
# 廃棄
# スポークスマン
# 警官
# 保守
# 表し
# 靴
# 全土
# 悩まさ
# ファシスト
# 取ら
# つつ
# 承認
# 発言
# いかに
# アート
# 起こる
# 育っ
# デイビッド
# ロイヤル
# ペべ
# プロセス
# 現金
# エンデュランス
# 普通
# ウィンターコルン
# 措置
# 始まり
# レーベル
# 急
# 取締
# エルドアン
# フォルクスワーゲン
# 続い
# ヒラリー
# ミケーネ
# ミス
# バローゾ
# 終わり
# 変動
# 思い
# あらゆる
# 上がる
# 扱う
# コスト
# 小
# 支払う
# ごと
# プレミアム
# 社債
# 解決
# 全
# 派
# ティナ
# ジョセフ
# 忠誠
# アンセルミ
# ニコラス
# 一員
# 南極
# ドス
# リットル
# 偉業
# 魅力
# 子孫
# 思っ
# 採択
# ベルギー
# 閉鎖
# 葉
# 肺
# 発達
# 記事
# コットン
# 米
# 対抗
# 排除
# 新
# 法王
# 相手
# 立法
# 下院
# ペア
# 率直
# 繰り広げ
# レーガン
# 当
# 波
# 釈放
# 中世
# あの
# ヨーク
# 優勝
# シーズン
# 首
# 介入
# 勤務
# ジョリオ
# 試料
# れれ
# ラボ
# 作っ
# 死亡
# 銃撃
# 非難
# 検討
# ドラマ
# 日曜
# 見なす
# マルコ
# チャット
# 遼
# フェニキア
# 肥料
# 契丹
# ルート
# 長年
# 分野
# 応じ
# ヒスパニア
# 医学
# 後悔
# 上院
# いえる
# 複数
# 神
# アウグストゥス
# シルト
# づけ
# 沈
# ラグーン
# アルコール
# 落とし
# ワイン
# ポンペイウス
# 劇
# 死
# 終わっ
# 詩
# 全般
# 司法
# 地位
# 重
# 変遷
# 石
# 通っ
# 称号
# 測定
# 別々
# 満月
# サーミ
# 展開
# 諸
# 反
# 灯台
# 依頼
# パルマ
# 大気
# 周囲
# 溶かし
# 貴族
# アルドリン
# 就労
# 壁
# 変わり
# バーゴイン
# 記録
# 干支
# 旧暦
# 記さ
# 焼失
# 対策
# カナン
# 青銅
# 中東
# 統一
# 型
# 見え
# 行き
# 論争
# 広がる
# ケープタウン
# 急速
# 峡谷
# 圧倒
# 流出
# 示す
# 機械
# 近隣
# 北海
# 黒海
# マグマ
# トーマス
# アントニオ
# 木製
# 地面
# タイトル
# 周辺
# 大幅
# 増大
# 良好
# 生態
# 嵐
# 砂塵
# 連れ
# 危険
# カヌー
# アラスカ
# 南米
# 超え
# 扱わ
# 水力
# 数々
# 聖書
# カンザス
# 解任
# ドナウ
# デルタ
# ウクライナ
# 属し
# ジェームス
# 失敗
# 平野
# 地形
# カデシュ
# 西部
# まず
# 流入
# 没落
# 満州
# ヤシ
# あるいは
# 加盟
# 民国
# 反応
# 空間
# 丘陵
# 国立
# 崩壊
# 北西
# 王朝
# 枝
# 送り
# 編集
# 儀式
# ノルウェー
# スウェーデン
# 絵
# アルバレス
# 指示
# 助ける
# 多大
# カルロス
# 亡くなる
# 構築
# 博士
# 証拠
# 果たし
# ディスプレイ
# 高地
# 平壌
# メートル
# ビル
# ゴール
# ジョゼフ
# 保つ
# 舞台
# 会議
# ラマー
# 礼拝
# 天津
# 同意
# 総督
# 女
# 挙げ
# 起源
# 火山
# 輸入
# 穀物
# 頼っ
# 建造
# 衰え
# 制作
# 演劇
# ツイッター
# 社
# 侵略
# 生産
# 商品
# モリコーネ
# 余儀
# 遂げ
# 番
# 祝い
# 北朝鮮
# 宣告
# トーナメント
# 出会っ
# 館
# ニコライ
# スノー
# 衝突
# マン
# 敷地
# カーソン
# ヘルツル
# 組む
# ディレクター
# ゴンザレス
# アナヤ
# 備え
# 働く
# ボランティア
# ポスター
# 祖先
# 地上
# 勃発
# 故
# 堂
# 天気
# 追放
# 基づい
# 洗礼
# 団
# 雨季
# アラブ
# 約束
# 本人
# 公国
# 所得
# 放棄
# スロバキア
# 低下
# 出発
# 高く
# 具体
# もたらし
# モイミール
# 中等
# 将来
# 留まる
# 執筆
# 恋
# 制圧
# トリックス
# サウスシー
# 大きい
# 裏付ける
# 広く
# フィリッポス
# 選ば
# ベニス
# 海峡
# 死後
# 明治
# 著しく
# 慣習
# 小型
# フォード
# ほか
# 再
# 栽培
# シチリア
# 家畜
# 統計
# 広範
# 譲渡
# 分割
# 兵士
# 西側
# 有し
# キューバ
# 君主
# 通し
# 初
# エル
# モナコ
# 満足
# 守ら
# 行政
# 大臣
# スパルタ
# 進展
# 気団
# 任期
# セクション
# ナイル
# 却下
# あたり
# 無
# 差別
# 熟練
# 日常
# 創設
# 先月
# 治療
# 恐れ
# 割合
# か月
# 背景
# 完了
# 残念
# ドレス
# 運動
# 女史
# 水上
# 引用
# 職人
# ニューヨーク
# 地図
# 控えめ
# クライン
# 考える
# 規則
# チーム
# 規定
# 賞賛
# 発行
# 状
# アボッツフォード
# 今朝
# つもり
# 版
# 当然
# グローバル
# はるか
# 役立つ
# 台無し
# 参入
# 疑問
# かかっ
# 引き出す
# レート
#
# 信念
# ステップ
# 長い
# バージョン
# 局
# 薬
# 選
# 作り出す
# 驚く
# 正しい
# ホルモン
# 事
# たる
# プロデューサー
# 雨
# 雲
# 店
# わかる
# 好き
# わかっ
# サイト
# テロ
# ピュー
# 住宅
# 着実
# 露出
# オプション
# 突然
# 酸化
# 大麻
# 国連
# 温暖
#
# 追加
# 効く
# 挑戦
# 夜
# 結ん
# 被っ
# 容疑
# ヘモグロビン
# 望ん
# クリス
# 年齢
# 例えば
# クラブ
# 捜査
# ユニット
# ポスト
# 気質
# 享受
# アシスタント
# 打倒
# 待つ
# 教える
# 受け取っ
# 地点
# 金額
# 取る
# ボール
# 賞与
# アナリスト
# 設定
# 大会
# 患者
# 韓国
# 停止
# 医師
# 上位
# コード
# 木曜
# マイリス
# 災害
# 製
# すぎる
# 石炭
# 部品
# 一番
# 会っ
# ラジオ
# 南東
# 多
# パーティ
# 果たす
# 生徒
# ダッフィー
# グレード
# グループ
# 失わ
# スポンサー
# ジャーナリスト
# 広告
# 求め
# 日間
# 強化
# 会い
# 規制
# 有権
# 収入
# 業務
# 想像
# 対象
# 明るみ
# ロビイスト
# 分離
# ガイドライン
# 鉄道
# 団体
# 額
# 比べ
# サラ
# 私的
# 南アフリカ
# ブラジル
# 稀
# 議員
# 入れ
# 豊か
# 掲載
# クリスチャン
# 料金
# 徴収
# 飛行
# スキャンダル
# 委員
# 階級
# スーパー
# しまう
# コマーシャル
# 浮き彫り
# ソーシャル
# うまく
# さらなる
# いくら
# リーヴ
# 豚
# たった
# よく
# 限定
# 最悪
# 美
# 手術
# 才能
# 示さ
# 基準
# 生存
# 大好き
# 子
# コンサート
# セガール
# 教師
# カレル
# 学ん
# 強力
# 救っ
# 訪れ
# 購入
# ひとりぼっち
# 交通
# 現
# 赤ん坊
# 顔
# 育て
# 政策
# 実験
# なさ
# 熟知
# 食物
# 園
# 気づい
# ロケット
# ヒル
# 表示
# 証明
# 感じる
# 白人
# リンカーン
# 知り
# 側
# 長期
# 交差
# 保存
# 異なる
# 興味
# アイデア
# 相違
# グラスゴー
# 取り入れる
# 伸び
# まさに
# 回答
# 作
# タルロ
# 起訴
# 広報
# カタラーノ
# 化学
# マーク
# オバマ
# 定期
# リード
# 生成
# 論者
# ファースト
# 感じ
# 事務
# 禁止
# しまい
# 恐ろしい
# イヴ
# 英
# サンローラン
# 没
# 香水
# もう
# 録音
# ペテン
# 見解
# オピウム
# ナショナリズム
# 気
# 案
# 中断
# ヒュー
# 練習
# カ国
# 週
# マーフィー
# 冒頭
# 信じよう
# プライス
# 名付け
# 宗主
# 赤ちゃん
# 取り付け
# バッテリ
# あたらしい
# スコット
# クリスティン
# ガムソン
# 失う
# スクリッティ
# ポリッティ
# 繋がり
# マクレガー
# 残す
# 併せ
# イメージ
# シンガー
# 明かし
# ユアン
# ソングライター
# 設ける
# ハルストレム
# ウェイト
# デッカ
# ラッセ
# 伝わっ
# 抜擢
# トレーニング
# 家康
# 海軍
# ネットワーク
# アバクーモフ
# ストーリー
# 保安
# 筋書き
# 手がけ
# リトル
# 仲間
# 次号
# ガイド
# まれ
# ナイトレイ
# 帆
# 図像
# ガース
# ドーセット
# ジェニングス
# メソアメリカ
# 友達
# 築く
# 奨励
# 究極
# 銀河
# 欠ける
# 防御
# キエラ
# トンプソン
# ヒッチハイク
# 倍
# アーク
# 居間
# コメディ
# コンセプチュアル
# プール
# 直系
# 組ん
# ウアシャクトゥン
# 徳川
# 確約
# サマセット
# 家系
# リーチ
# スター
# 殺そう
# ウェルズ
# 関わっ
# 選集
# アンドレ
# サイエンス
# ケイラ
# コミック
# ベリヤ
# 原子
# アンジェル
# ランボーズ
# ブック
# マーベル
# サノス
# コンテ
# 極悪
#
# エドワード
# サーモン
# ボーイ
# カーター
# ジミー
# 鋼
# 現職
# ファロン
# 行く
# 弟役
# プレイ
# イレーヌ
# 気楽
# ボガート
# ハンフリー
# サブリナ
# マイケル
# 学ぶ
# 麗し
# イラン
# メイヤー
# 人質
# 前兆
# 街
# 留まっ
# 歌っ
# マルセル
# 部屋
# 残さ
# スミス
# 殺し
# 議席
# 切削
# せよ
# 忘れ去ら
# 小説
# 刑務
# スカイラーク
# ヘプバーン
# オードリー
# 尊敬
# シード
# モントリオール
# 塔
# ゲスト
# アナウンサー
# 前回
# オズボーン
# 弟子
# ヤジディ
# 抱き
# 騎士
# エラニ
# ブシャール
# セシリー
# ゴーント
# プランタジネット
# ジョーン
# 解雇
# オフ
# 持ち帰っ
# 女優
# 恋心
# スピーカー
# ハンス
# 熱い
# ペテルソン
# 原料
# アルファ
# 放出
# 改良
# 進化
# 離婚
# ホールデン
# 円盤
# グロリア
# ラジウム
# モーモネ
# 退院
# ピアフ
# 距離
# ウィリス
# ゴードン
# 造船
# レヴィット
# ルーパー
# ヴァレンティノ
# ステレオタイプ
# テネシー
# 守る
# エア
# 置こう
# クライド
# 未来
# 神学
# シェンク
# マットレス
# ブルース
# ジョンソン
# ライアン
# ベル
# フィッシング
# 同年
# マペッツ
# ピギー
# 受付
# 係
# 工業
# ストーラー
# ジェイソン
# シーゲル
# 移し
# 憧れ
# ウェディング
# 泣き
# ナッシュビル
# 黙示
# 備わっ
# ロミオ
# チェンバレン
# 内閣
# 現役
# 生き残っ
# 演説
# 両国
# 未遂
# 暗殺
# 検問
# 経
# チェコスロヴァキア
# 入ろう
# ズデーテン
# 農民
# チェコ
# 警備
# 着手
# 対面
# 本来
# ヒトラー
# ジュリエット
# 一作
# ノーマ
# タルマッジ
# ヴァレンティ
# 神秘
# 願い
# 押し付け
# 配役
# 原則
# マルクス
# ハリファックス
# ブロッホ
# 枢密
# 議長
# 結成
# 間違っ
# イーガン
# 熱望
# ミリス
# 民兵
# 処刑
# ド
# エリック
# チャーチル
# 好意
# 見せる
# 事前
# 公的
# ヘロイン
# 溺れ
# 下り坂
# エイズ
# 至っ
# キャランジ
# 描い
# 終盤
# イーグル
# 改正
# 搭載
# 掃討
# レジスタンス
# 中尉
# マンドル
# 割譲
# 上海
# 広州
# 居住
# 恐竜
# 襲い掛かり
# 飲む
# 開港
# ほど遠い
# 時点
# 親衛
# 付き添っ
# 発明
# 信号
# 炭酸
# 錠剤
# 領域
# そそら
# ソルヘイム
# ダルナン
# まずまず
# キガリ
# 遅
# 減っ
# 未熟
# さえ
# とても
# 軍部
# 新しく
# コンゴ
# ザイール
# ルブンバシ
# 占拠
# 母親
# シンプル
# 悩む
# 主人
# 簡潔
# ゴールド
# ソール
# バス
# 閉じ
# 人材
# 好ん
# かつ
# 路
# 遅らせ
# アンテナ
# 方向
# しめ
# ベルリン
# 空輸
# 満たす
# 遠い
# 誘導
# 管制
# ダイポール
# 用い
# 滑走
# 角度
# 分解
# 能
# オペレーター
# 精度
# 抑える
# 確認
# 以下
# 口頭
# 種族
# 南京
# 敗れ
# メッセニア
# なめし皮
# 毛糸
# 皮革
# 原理
# ワット
# 小学
# 金属
# 需要
# 作り出し
# ペロポンネーソス
# 他人
# 関与
# カー
# センチュリー
# アメリカン
# モータース
# 裏付け
# ランブラー
# 駆り立て
# 緩ん
# 生
# 東南
# 姓
# 概念
# 徴募
# 大軍
# 攻勢
# 道徳
# 気持ち
# ルネッサンス
# 成っ
# 出産
# 担う
# 耕作
# オオバコ
# てる
# 着け
# 草地
# たくさん
# 身
# ピテクサエ
# クーマエ
# 送り出し
# バナナ
# 勧め
# 皇族
# 戦う
# 隕石
# 壮大
# 突撃
# 存続
# 壊滅
# 断言
# 染色
# 遺伝
# 材料
# 源
# 定義
# ウェラー
# 性質
# 歌う
# 熱心
# 湖南
# 湖北
# 淵
# 林
# 則徐
# 忘却
# 騎兵
# チャンドラー
# ステーション
# 千
# 飛ばし
# 以後
# 載せ
# 改める
# 諡号
# 発芽
# 昭和
# 存命
# 百
# 殺害
# 剣術
# 元素
# 著しい
# 利点
# イリジウム
# 静的
# 機動
# 騎馬
# 乗馬
# まま
# 記者
# ラブロッカ
# パートナー
# 牧師
# 上り詰め
# チャート
# ペニストン
# ウィズ
# 魔女
# グリンダ
# ウィルクス
# 庶民
# ひび
# 機内
# 決議
# 次点
# 公表
# 再選
# 除名
# グラフトン
# インターフェイス
# 知能
# 人工
# トーリー
# 与党
# あと
# 失速
# ビルボード
# 戦時
# 寛容
# 幸福
# 追及
# 表す
# 名詞
# 共産
# 便利
# ほう
# 終焉
# 抵抗
# 漠然
# 人道
# 空港
# シングル
# 自宅
# 絶頂
# 乗客
# 同社
# 注ぐ
# ロサンゼルス
# 復帰
# パバルカル
# 敬けん
# 輝き
# ディスパッチ
# 炎
# 包ま
# ケンゼス
# 歩き去っ
# エリオット
# サード
# 葬式
# 参列
# ドライバー
# ヌード
# 自社
# 具合
# ミュージシャン
# トム
# ロビンソン
# 返り咲き
# 呼ん
# スティーラーズ
# ホイール
# ルイス
# 切り替え
# 祈り
# 翌年
# メイト
# 信心
# 品行
# ぞっと
# 皇太子
# カンバーランド
# ストラサーン
# 姦通
# 挫折
# 未亡人
# ピアノ
# アン
# ホートン
# サムスン
# 金遣い
# 荒
# ファーウェイ
# シガー
# ロス
# フョーグル
# 主題
# 仕上がっ
# アニメーション
# サイズ
# 野望
# ユニバーサル
# 存分
# オスワルド
# 知的
# 軍用
# 実物
# ヘリコプター
# ミニチュア
# 制服
# ハック
# 手当
# 修復
# プラボウォ
# スビアント
# インドネシア
# ジョコウィ
# 就任
# 退任
# ユドヨノ
# 見せつける
# フォーラム
# 減額
# ホーマー
# レヴェレンド
# ウィリアム
# ヘクラー
# ギター
# プレーヤー
# 紹介
# レニー
# 運
# 独身
# 追う
# イレイン
# スパイ
# ジェッセ
# 叶える
# 決意
# ハマースミス
# コロナ
# ステージ
# 灼熱
# 肌
# 補助
# 燃料
# パワー
# 認定
# ノッティンガム
# ジャーナル
# スタッフ
# 半
# キリエムア
# 売上
# トール
# 教え
# セキュリティー
# ノンフィクション
# スコッツマン
# レノックス
# 諜報
# 夫人
# ダグラス
# 容易
# 曲線
# マインド
# ジレンマ
# 取組
# 求人
# 背後
# 読ま
# アレクサンダー
# とる
# キム
# 正式
# 伝記
# オペラ
# ブロガー
# ジェッツ
# 演出
# 楽しん
# アドバイス
# 妹
# 提起
# 見出す
# バリー
# イーブニング
# クーラント
# 批評
# 卒業
# 修士
# 取得
# 関わら
# 自己
# 狭め
# 輝い
# 問わ
# シュプリンガー
# 精力
# 融和
# 追求
# イスラエル
# シャレー
# 焼け落ち
# 翌
# 友誼
# 勲章
# ヴィギエ
# ル
# コント
# 福祉
# 移住
# カルカソンヌ
# 要塞
# アムネスティ
# インターナショナル
# 魔法
# 公私
# ブレーメン
# ベルリングハウゼン
# コロン
# 払っ
# ディジボーデンベルク
# ルペルツベルク
# 追わ
# アイビンゲン
# 移っ
# 恋人
# シュドバーデン
# メルディンゲン
# 移り
# ウルリッヒ
# メダル
# 走り
# 検閲
# 好ましく
# 言論
# 参加
# 衣服
# 血痕
# 上旬
# バイス
# 新聞
# ブランズフィールド
# 両者
# 谷
# 隔離
# 地理
# 特性
# がた
# 運命
# 母国
# 全域
# 商業
# 前哨
# 基地
# プリュヴィオーズ
# 恐怖
# 緩和
# べく
# バーナード
# タピー
# 全額
# 各地
# 装備
# 難
# 陥っ
# 山岳
# 分かれ
# 陸地
# コミュニティ
# パーマー
# 充填
# 群集
# アーネスト
# シャックルトン
# 集まっ
# 号
# 乗せ
# 出航
# 立案
# 制定
# 威風
# ピュロス
# 離れる
# 暗黒
# 抜け出よう
# 識字
# 忘れ
# 修正
# 創案
# ギリシア
# 平等
# ヨーゼフ
# サキブ
# ゲート
# 全長
# プラネタリウム
# 庭園
# 水族
# サンフランシスコ
# 憩い
# リラクセーション
# ガーデンズ
# モスコーニ
# センター
# 屋根
# マーチン
# ルーサー
# キング
# モニュメント
# 納める
# 時刻
# 事象
# 系列
# 熱
# っぽく
# パーク
# ゴールデン
# ボスポラス
# 説
# 劇団
# 従業
# 終結
# 免れる
# ヴュルテンベルク
# 綿
# 工場
# 製造
# ゲオルク
# ライヘンバッハ
# 売却
# ブロック
# 元来
# そもそも
# ピーター
#
# オーバーマルスベルク
# 役所
# さかのぼり
# 一新
# 去っ
# イスタンブール
# 阻止
# フランツ
# 目撃
# 歌
# 感激
# アンコール
# 閉会
# 転換
# 早く
# スエズ
# 動乱
# 保有
# 限界
# 見せつけ
# 掌握
# 奪回
# 会場
# 散発
# バルト
# 勝ち取っ
# ハンガリー
# かける
# 脅し
# 兼
# 賛美
# 滞在
# 艦艇
# 隠密
# 広い
# さかのぼる
# 恐らく
# 銅器
# エッツイ
# 凍結
# ミイラ
# かれ
# 銅
# メッキ
# 苛烈
# ベルサイユ
# 法廷
# 震撼
# 周知
# パン
# 高騰
# 欠如
# 高まっ
# 騒然
# 亡命
# 逃れる
# 帰国
# プレッシャー
# 地殻
# ティポ
# アンドイノ
# リナレス
# 絶た
# 進歩
# 途切れ
# 犯
# 倒産
# 招く
# 生まれる
# 外側
# 結ぶ
# 架空
# あたる
# キャピトル
# サラトガ
# 打
# 一層
# インディアン
# 一団
# 収用
# 沈み込み
# 海洋
# オールバニ
# 造山
# 減らす
# セシリア
# わたり
# 職業
# 芽生え
# 夕食
# 友情
# 協業
# めぐっ
# ひび割れる
# コラボレーション
# 付ける
# ソリューション
# アントニ
# ガウディ
# アプス
# 違う
# フォロー
# 支え
# 横向き
# 西縁
# 遠征
# 足止め
# 苦境
# 収録
# カプア
# 軍団
# 執り
# コリ
# 違法
# クリオ
# 知らさ
# 護民
# 補佐
# 守っ
# ブログ
# 元老
# 執政
# 立ち向かう
# 禁じ
# 撤回
# 公衆
# 大いに
# 政敵
# 丸腰
# 友
# シューマン
# デュエット
# ハドソン
# ディー
# フリーマン
# 応戦
# 黄金
# 近世
# 月曜
# 外在
# 史
# 話者
# ルイ
# フェリペ
# 王室
# 叔母
# イサベラ
# 王位
# 継承
# エンリケ
# ブエノスアイレス
# 商法
# 拡充
# 任命
# キキ
# 言動
# ブルーノ
# 脇
# 仮説
# ヴィラ
# ペルッカ
# 馬
# 北東
# メリット
# 隣
# ヘクタール
# 火事
# スタンド
# 厩舎
# パウロ
# バチカン
# 途方
# 犯行
# 取り除か
# 硬貨
# コレクター
# 本質
# 貨幣
# 重視
# 内側
# 因子
# 断層
# エンニオ
# 島々
# 遠く
# ティンティン
# 起用
# 抱い
# 基づく
# ウォルト
# サポート
# 実ら
# ジョルジュ
# ジャーメイン
# ロゼネ
# 休暇
# のち
# 少女
# 不倫
# 下部
# 眺め
# 木
# 愛情
# 夏期
# ハリケーン
# 平ら
# 立石
# ドルメン
# 先史
# 浴びる
# マレンゴ
# 諦める
# 強いる
# ビルヌーブ
# 艦隊
# 封鎖
# 置い
# アウステルリッツ
# つながる
# 破ら
# グランヴィル
# アレクサンドル
# 実践
# フィオレロ
# プロテスタント
# ウォルター
# 語り
# オリヴィア
# ゴフレド
# ペトラッシ
# ボナパルト
# なれ
# 将校
# アプリア
# 遺跡
# アプリアン
# カラブリアン
# 建国
# サムニウム
# モリーゼ
# 東方
# バジリカータ
# 著者
# クラウチ
# 砲兵
# ステファン
# 焦点
# 当てる
# 断念
# 一握り
# 領地
# 象徴
# 対仏
# コルシカ
# シアター
# パペット
# 稼働
# 悪ふざけ
# 同士
# 内紛
# 夫
# 在任
# 含め
# 謝罪
# 再生
# 総裁
# 洋上
# 風力
# うる
# 株価
# 国勢
# 好
# 景気
# ルーカス
# クラナッハ
# 父
# 絵画
# 引く
# 従っ
# 取引
# 逮捕
# 徴候
# 今回
# 業者
# 極めて
# 言葉少な
# 事故
# ラリーバンス
# 人
# 沈む
# 海上
# 不時
# 着
# シュピーゲル
# タンザニア
# 洗浄
# ボーイング
# ランディング
# フラップ
# 結論
# 下し
# 再度
# 為替
# させ
# 退屈
# 消え
# 妨げる
# みなし
# 過
# 半数
# サン
# ゴーダン
# オート
# ガロンヌ
# 市長
# 履行
# 中止
# ラチダ
# ダティ
# サルコジ
# 予備
# 法務
# 被疑
# ブリス
# ホテフュー
# 被害
# ばか
# 内務
# 刺客
# 三
# 成し遂げる
# 通信
# はず
# アーチスト
# 会員
# 有効
# 年々
# 侵す
# ばかり
# 若者
# 脳
# 合同
# 遺産
# 最
# あたら
# 違っ
# コミー
# 言及
# アカウント
# 核
# 兵器
# かく
# 嘲笑
# 話す
# 作者
# 休息
# 墓
# ナロー
# バー
# はっきり
# 写っ
# 人
# スエーデン
#
# 繁殖
# 上陸
# パーカー
# 秘密
# 部員
# 一時
# 充足
# あらまし
# くれる
# 償還
# たろう
# 迎える
# 欠席
# 通知
# やめれ
# タッチ
# 噂
# 石灰
# 上方
# サラマーン
# 老練
# 財務
# モハンマド
# アルジャダーン
# 交換
# 石油
# 小麦
# 天然
# 資源
# 達成
# 打ち立て
# デビッド
# 退職
# 要請
# 他者
# 除外
#
# 古く
# 得する
# キーボード
# 労使
# 見地
# 旧弊
# いまだ
# 席巻
# 孤独
# シナリオ
# 馬鹿馬鹿しい
# 何百
# 相応しい
# アプリ
#
# 秒間
# カンジル
# オーストラリアン
# 大騒ぎ
# ファイナル
# セリーナ
# ジャメカ
# ウィリアムズ
# 喫し
# 目覚まし
# 時計
# 格闘
# 信じる
# 一群
# アヒル
# 不思議
# オルガン
# エリート
# 不調
# クーン
# 振る
# 不審
# 危機
# 魅惑
# モンスター
# マッシュ
# 演奏
# ゆく
# ボイスト
# 不備
# サイモン
# クレッチュマー
# 荒廃
# 気味
# バラック
# ひとり
# 手探り
# 証人
# ポトマック
# 電信
# 総長
# おかげ
# 全員
# 昨日
# 送ろう
# バロン
# クラレット
# ペドロ
# サンチェス
# フェデリコ
# フェリーニ
# 道化
# 影
# 笑顔
# 引き出さ
# カウボーイ
# 題材
# 殴り合い
# 皮肉
# 暗示
# 常用
# 口語
# コスペダル
# 国防
# 合っ
# ジャガイモ
# 知事
# クリスティーナ
# シフエンテス
# ハビエル
# マロート
# 次官
# 堅苦し
# デュラン
# アンヘル
# ピンタド
# 会計
# 失業
# 下回り
# 陣
# さらさ
# 強行
# ファティマ
# バニェス
# 誇り
# 課題
# 熱々
# 応酬
# 互い
# 難局
# 広場
# 戦線
# 党員
# 祝っ
# メイ
# メトロポリタン
# ブレグジット
# 公然
# 対応
# 万人
# 気晴らし
# 野外
# 劇場
# ミヒャエル
# 聖堂
# 階段
# 魅了
# 献納
# 祭
# 個
# 火災
# 報知
# サンディニスタ
# ヴィクトワール
# 爪弾き
# ムンド
# ドタバタ
# 喜劇
# ふさわしく
# 音節
# 作物
# 掘り起し
# 謎
# 縛ら
# こみ上げる
# 涙
# 瞳
# 曇ら
# 形づくる
# クリア
# 集まる
# 懸念
# 早期
# 今度
# 投じる
# 不明
# 野党
# マドリード
# 出席
# プライベート
# フィガロ
# 投じ
# 良く
# ジョー
# 社長
# カステル
# フランコ
# ヴェネト
# 性向
# 教徒
# ジョージタウン
# 身近
# 繊維
# 権利
# マドリッド
# 思え
# 全的
# 絶対
# シェパード
# 当該
# 支給
# バウチャー
# 証券
# 審議
# サミット
# 提言
# ゴンドラ
# 机
# 置く
# 許容
# 目次
# ギラード
# 相談
# 備考
# 加え
# 手引
# 緊急
# 条項
# スターンリーブ
# 両
# 大審
# 棄却
# 上訴
# 差し引い
# 考慮
# 入れよう
# 社員
# 渡さ
# ガソリン
# 値上がり
# メストレ
# トレ
# 運転
# 手伝う
# 思考
# オートバイ
# ヘルメット
# 事例
# バレンティーノ
# ロッシ
# ヒューマノイド
# ロボット
# 理事
# ウォール
# シリコンバレー
# 続々
# 増える
# アマゾン
# 時価
# 総額
# マウンテン
# ビュー
# ズッカーバーグ
# マルタ
# カサ
# 態度
# 付加
# 税
# 数値
# 新駅
# 単一
# 通貨
# ノマ
# コラード
# パッセラ
# オファー
# フランシス
# 取り下げる
# 上述
# 特権
# 代案
# 優れ
# 去る
# 記し
# 会合
# 語ら
# 悪い
# 論ずる
# フィリピン
# カスタム
# 追跡
# ローテク
# アプローチ
# マイクロ
# 水曜
# 最愛
# 勝負
# 殺さ
# ベガ
# ミーム
# デリー
# ステッカー
# 船上
# フィード
# 接続
# 動き
# 乗組
# 単なる
# どころ
# 向上
# ドローン
# 推進
# くれ
# 火力
# 装い
# 光り
# ネガン
# ジェフリー
# ディーン
# モーガン
# ガイ
# 余裕
# ノーマン
# 相棒
# バダープール
# 感情
# 引きこま
# アフター
# トーキング
# デッド
# どうぞ
# 起ち上げ
# バラット
# 尽力
# 腹立たしい
# 願望
# キャスト
# 踏み台
# フェンス
# 飛び越え
# 納屋
# やつ
# 売りとばさ
# ね
# ジョーク
# ジョニー
# 登壇
# 背中
# 郊外
# コンテスト
# 座る
# 泥
# だらけ
# 履い
# 男の子
# ウォルマー
# カーニバル
# ライバル
# 隔てる
# 切り抜け
# ハイテク
# 席
# 潔く
# テニス
# ワン
# オール
# 対戦
# 優雅
# イスナー
# 賛辞
# キャンペーン
# 疎遠
# かまし
# 鞭
# ふざけ
# 入り込ん
# オルニー
# ナイン
# 酷い
# ゴルファー
# プレミア
# はったり
# 真似
# シングズ
# アレハンドラ
# 冊
# 分かっ
# 柔らか
# 合わせる
# 大量
# 望み
# 後戻り
# 止まっ
# 帝王
# 連続
# チャンス
# 期日
# 取り戻す
# 書き
# 正しかっ
# マント
# 聖職
# 電動
# バイク
# 実用
# 決める
# さばき
# 有害
# ダビッドソン
# もっぱら
# オン
# まるで
# 侵害
# 悪意
# こ
# 走っ
# 実存
# 国土
# 保障
# 出かける
# 持ち合わせ
# 走ら
# 為さ
# 激戦
# 立ち向かわ
# でしょう
# 前進
# ゼロ
# 物々しい
# 傲慢
# ハーレー
# 出さ
# ストレンジャー
# 短く
# 好む
# 人権
# 挑む
# ワールド
# 夫妻
# ハウス
# ブッシュ
# 関わり
# たとえ
# 面白かっ
# 悲しい
# シーン
# 省き
# カップル
# ミルドレッド
# 描く
# 休日
# セレブ
# ファン
# レポーター
# 親
# 食欲
# 時分
# 売り払っ
# 是認
# 株式
# 先物
# サイド
# 並ん
# 急増
# らしい
# 書き込み
# 国債
# 蓄積
# 飽く
# 借金
# 喜ば
# 庁
# 発し
# やっと
# 前向き
# 取り組む
# 鶏
# 唐揚げ
# 創造
# 痛ましく
# ファイル
# 階層
# アミュンタス
# ノリ
# 従属
# アケメネイド
# ベース
# マイアミ
# 終わる
# ペルシャ
# 上級
# 抱か
# 冷静
# 姻戚
# 偏見
# アスティ
# フィルム
# おさめ
# ヤニス
# スマラグディス
# 脅威
# グレコ
# パオニア
# ゼイ
# たわ言
# ダリウス
# 復活
# 仕上げる
# メガラ
# 追いかける
# 神経
# ビザンチウム
# コネクティブ
# 提携
# 維持
# 司令
# ゼイオン
# メガバズス
# 流れる
# 難しかっ
# レコーディング
# 関わる
# 責務
# 負っ
# パソコン
# ノート
# 厄介
# 付き
# 不快
# 表明
# あてつけ
# 発想
# 増々
# 総観
# 確証
# モンスーン
# レディ
# 季節
# 卓越
# 先駆け
# 予報
# スラヴ
# 意
# ゲルマン
# 遺憾
# スラブ
# 信用
# 末
# 南西
# ザーホリエ
# がましく
# 親身
# 認める
# 統括
# 形
# つれ
# 調印
# 激化
# 国務
# ヒステリー
# ドメニコ
# ディ
# メンバー
# パトロール
# 演じ
# 巡視
# 埋め立て
# フォンヴィエイユ
# 拡張
# プラン
# ウェールズ
# 手続き
# 違い
# ベルシェロン
# 素敵
# 感
# 納税
# あばこう
# 告げる
# 出現
# 煽っ
# 変革
# フィート
# 埋め
# 無視
# アリス
# 通勤
# 応え
# マハナコーン
# ウッズ
# 駆逐
# 感覚
# いくばく
# ぼんやり
# 粗い
# 橋
# 老齢
# タイプ
# 高層
# 幻想
# 基金
# ヤス
# 離脱
# 救い
# 形式
# ケスチーベン
# リニア
# モーターカー
# 試験
# チケット
# 入れる
# マリーナ
# 限ら
# サーキット
# 絶妙
# タイミング
# 更新
# 栄光
# 照らさ
# 訪れる
# 冷戦
# バンコク
# ホアン
# サルサ
# 意義
# プラトン
# カプラン
# 読ん
# 冬季
# ユニバーシアード
# クラスノヤルスク
# おののき
# 遅く
# 委ねる
# モルディブ
# グラニット
# タイガ
# セーシェル
# ティオマン
# セントヘレナ
# つながり
# 無人
# バハ
# カリフォルニヤ
# 小島
# スキタイ
# シベリア
# 回顧
# 彫刻
# 商人
# 外観
# ディテール
# 故人
# 思い出
# 生き生き
# 殺す
# 憲章
# 溢れ
# 代議
# ダイヤモンド
# 最北
# マンガン
# 鉛
# 亜鉛
# ニッケル
# コバルト
# モリブデン
# 鉱石
# 鉱物
# 豊富
# クリック
# 添付
# グアム
# よい
# デザイン
# 取り締まっ
# アンドリュー
# マー
# ジュエリー
# 美術
# 終わら
# 没頭
# 引き分け
# 弱
# 麻痺
# 働き
# ホーム
# レトロ
# がっかり
# モンテカルロ
# ブノワ
# ペイル
# ロッコ
# 番狂わせ
# 防止
# トロピカル
# イライラ
# 干渉
# キンマ
# ナット
# 樹皮
# ランドスケープ
# ヒキガエル
# ナマズ
# まわっ
# オフィス
# 移譲
# 笑う
# カラー
# フランク
# 宣誓
# 取り上げる
# 人民
# 贔屓
# ノーサンプトン
# 先導
# 任務
# 就く
# デイビス
# アンケート
# バッファロー
# 卸
# 酸性
# 会長
# 昇格
# 発覚
# ブリグジット
# 縮小
# 買い物
# 客
# 好調
# 小売
# ハーバート
# 早送り
# ミネラル
# 赤字
# 土壌
# 限度
# 毎月
# 養分
# 欠かせ
# 健全
# ディエス
# メーカー
# 負担
# 成果
# 心配
# 終始
# ホープリー
# リスク
# 気づか
# 済む
# 聞く
# 得よう
# 虚偽
# 数百
# 自動
# ノイズ
# 下げ
# 自尊
# 腹立たしく
# 辞職
# 賠償
# 請求
# 裏地
# 銀
# 布
# 珍味
# エーオン
# 狩猟
# 検索
# ネイチャー
# ドクター
# リー
# 言い足し
# 窮地
# 近代
# 子育て
# 憎しみ
# 軽々しく
# アゴラ
# 野獣
# 漏れる
# 世間
# 講じる
# 外部
# ぴったり
# ファイアウォール
# 試みる
# いか
# 制
# ポリシー
# ブービー
# スタンス
# モロッコ
# 日記
# パックハム
# 司会
# アヴェリー
# 大望
# 相互
# 訴訟
# 請願
# 目立つ
# 歓迎
# 鳥類
# 王立
# ライセンス
# 死滅
# ツノガレイ
# ナッツ
# ヒラメ
# キダラ
# ジェフ
# 面白く
# トラップ
# 蛹
# 横
# 各駅
# 赤い
# キャップ
# ガード
# プラットフォーム
# 車輪
# 点検
# ハンマー
# 列車
# 歩き
# つづけ
# 優しく
# 車台
# ノック
# 朝市
# 多用
# ポン
# 菓子
# 蜂
# 繭
# 尖塔
# 南方
# すなわち
# 浮かん
# アクティブ
# ディフェンス
# コンセプト
# 設置
# 話題
# ディスカッション
# 鉱脈
# 集める
# いじる
# 長く
# ウィントー
# 見れ
# モトクロス
# カバー
# しみ
# サングラス
# 停まる
# ベリンガム
# しばし
# 電車
# 硫黄
# 固定
# 全く
# 角
# 意外
# きらめき
# 武装
# ミリカン
# スカーフ
# 壊れ
# やすい
# 落ち着か
# オディ
# 動い
# 絶する
# ヒーロー
# ナチス
# テキスト
# 取り扱っ
# ジマー
# 一連
# 暗い
# 真
# 苦労
# ジーンズ
# 訴えかける
# 為
# ふさわしい
# 疎外
# ホスピタル
# 視点
# 陽気
# お祭り騒ぎ
# 硬い
# ヘルス
# バランス
# 午後
# あつらえ
# 持た
# 懐っこく
# 温まる
# めった
# 楽し
# 発信
# ボブ
# 瞬間
# 巡り合う
# よそ
# 衝動
# 起こら
# コーポレーション
# 罪
# 強硬
# ミセス
# もの作り
# 執念
# 不安
# 良かっ
# 調子
# 鍛え
# ラグビー
# 弾い
# 委託
# 審理
# わから
# 上告
# 前後
# ひっくり返っ
# 従う
# 測ら
# 滅多
# 開き
# 触覚
# ウェンハム
# サンダー
# 拷問
# ランド
# 村
# パスワード
# 話し
# 賛成
# もし
# 逆戻り
# 羊毛
# さも
# コーティング
# レイチェル
# トレンド
# 軟化
# サウス
# バンク
# タワー
# アパート
# 疲れ
# インテリア
# 展望
# 観客
# ハリウッド
# 保持
# 要望
# アップグレード
# アディダス
# 浮かぶ
# ヴァンテージ
# 無料
# 開設
# テスコ
# きれい
# 夫婦
# 喚起
# 資産
# レポート
# 注ぎ込む
# ゴミ
# 劇的
# かなっ
# 限り
# 魚
# プラスチック
# 天才
# 指定
# 下落
# リハビリ
# 区別
# アブロエナジー
# ネクター
# 高価
# 前払
# 運勢
# 債券
# 借り
# 受け取れる
# 預金
# 貯蓄
# 持ち
# 残高
# とどめ
# させる
# アビバ
# インベスターズ
# マルチ
# 戦略
# リターン
# インカム
# 外科
# 目下
# 数え
# 披露
# 打ちのめす
# たかっ
# ただ
# 静脈
# 浮き出
# 立場
# 震え
# グレンダ
# 技
# 咎める
# もしくは
# 何十
# 時事
# スクール
# ビジネス
# ハーバード
# 検出
# マイク
# 落とす
# アンバサダー
# 以っ
# 資格
# 理
# 過小
# 民衆
# 負う
# 力説
# 天候
# 不良
# 大人
# けが
# 害
# 寒く
# 水準
# クレジット
# 債務
# 言え
# シェークスピアー
# カンパニー
# マラー
# サド
# 借り入れ
# 科
# 演じる
# スラ
# 及ぼし
# 西暦
# トルドー
# 命令
# 明瞭
# 多かっ
# 了解
# 目指す
# 望む
# 皆
# 促す
# 出す
# 礼儀
# ティベリウス
# ボート
# 祭儀
# 立て
# 利益
# 列
# マスト
# スポット
# 南北
# あれ
# 都度
# サレルノ
# なん
# 犯罪
# 寡黙
# 滞砂
# 圏外
# ビアン
# 供述
# あいまい
# 駆使
# 浚渫
# 履歴
# 思しき
# 高校
# 特使
# 宮廷
# ホームレス
# かど
# 力量
# 刺殺
# 十
# 交渉
# いき
# 祭壇
# 正
# 安石
# 正月
# パップワース
# 該当
# ケンブリッジシャー
# 猿
# 周年
# 当たる
# 縁起
# 週日
# 仏像
# 華人
# 月日
# 饗宴
# こよみ
# 計算
# 毎年
# 膀胱
# 努め
# 変異
# タバコ
# 伺え
# 曜日
# 生年
# 方形
# スキャン
# 水鉢
# 備え付け
# 巨石
# 議題
# やめ
# わかり
# 右肺
# 高台
# 戦火
# 引き起こさ
# 出生
# カルナック
# 寺院
# 碑文
# 参考
# テルアマルナ
# アッデンブルック
# ゲゼル
# 誓っ
# 通
# 感心
# 役人
# 吸っ
# 物資
# ラメセス
# 戦術
# 低減
# 確か
# ブレステッド
# 学術
# 再現
# 称賛
# ロメス
# 包囲
# 急い
# 行え
# 有毒
# 戻り
# アムル
# チューニップ
# スモッグ
# 詰まる
# 経過
# 着用
# 捕えよう
# 蒙古
# 胴
# 中傷
# 素朴
# ピクニック
# ベンチ
# 小道
# 伴い
# 急激
# 築か
# 地元
# 公共
# マイノリティ
# アップ
# サポーター
# 項目
# 見なし
# 総統
# 袁
# 世凱
# 後継
# ギルボー
# 目の当たり
# 面倒
# よろい
# 沈括
# 木馬
# メカニズム
# 統合
# 基盤
# 罰
# 従事
# 倫理
# 嫌々
# 知識
# トロイ
# インスピレーション
# ラチウム
# 平凡
# 老衰
# 戦場
# 若く
# 聴聞
# 拘置
# 不死
# 予言
# ジュリアン
#
# 砦
# 装着
# コリント
# 喉
# アンティパス
# ヘロディアス
# 毎日
# エルサレム
# ピラト
# イエス
# 試練
# 新約
# 例外
# 定住
# 閏月
# 中産
# 金曜
# ニュートン
# 位相
# 確定
# 霧
# 罰金
# ヌーベル
# 北方
# 生涯
# ニトラ
# 標的
# マレウス
# 君
# ソニー
# 反し
# 施さ
# 幸い
# セファルディム
# 尋ね
# ポルトガル
# マデドニア
# 審問
# 東側
# ネストゥス
# メスタ
# アイデンティティ
# テッサリア
# 打ち破り
# 罰則
# テルモピレー
# 山道
# 団員
# 異端
# アカイア
# 形勢
# 武力
# 一因
# 緊張
# 解消
# 従来
# 調和
# セーガル
# クリミア
# 優位
# 文節
# 務め
# 退行
# 持ち込ん
# ドミニコ
# 併合
# ハインリッヒ
# クレイマー
# ザルツブルク
# 司教
# 助手
# 型破り
# 固く
# 待っ
# 余り
# 西洋
# 接触
# 有利
# 開け
# つながっ
# ヘア
# 活躍
# 除去
# 小さい
# 集中
# 集積
# キューティクル
# 州兵
# つけ
# 集結
# 兵站
# 槽
# 毛髪
# 米軍
# プエルトリコ
# スコタイ
# 今夜
# 深セン
# パール
# 奪取
# マケドン
# 招集
# 奥
# 作戦
# 女帝
# エカチェリーナ
# 遂行
# 処罰
# ハーバー
# 見せ
# プロパガンダ
# ロマノフ
# ビーム
# 理想
# ビジョン
# 実態
# 盲目
# ハイ
# きざし
# 低
# 明るい
# 取材
# 名乗っ
# 春分
# 秋分
# 日の出
# 最小
# 偏差
# 合わせ
# 太陰
# 乱闘
# ユカタン
# 憶測
# 夏至
# 署
# 単に
# 偶然
# 報じ
# 弱い
# クアロン
# 段階
# 分断
# カラカラ
# 冬至
# 標示
# ラッドヤード
# 取り組ん
# 名目
# ビバリーヒルズ
# ホテル
# 誘わ
# ハプスブルク
# 神聖
# 癌
# チャールズ
# 熱意
# 任意
# 観察
# 公妃
# 嘆願
# 提出
# 迫害
# 付け足し
# 組み合わせ
# 天文
# 台
# 太陽
# 設け
# 美し
# 低く
# 収益
# 武術
# ベオグラード
# サハリン
# カムチャッカ
# 近年
# 確率
# 要因
# ウラジオストク
# 損失
# 極東
# 男子
# 解釈
# 言い
# 占める
# ギタリスト
# 鋭敏
# 納得
# 賑わし
# 給料
# 加わる
# 申し出
# 心理
# 感動
# 喧嘩
# グラビティ
# 乗っ
# フローレンス
# ガラード
# 出会い
# 負傷
# 落ち
# スティーブン
# ウィーラー
# 欲求
# セルビア
# 言い合い
# ラホール
# 編
# ガゼット
# 国籍
# 金瓶
# 梅
# 昔
# 取り入れ
# 適さ
# スポットライト
# 高麗
# お腹
# 仙
# 複雑
# シュライ
# 湾
# 告げ
# フーズム
# 湿地
# 凍っ
# 直
# プロイセン
# 尾骨
# 避難
# ボエーム
# 火器
# 砲
# フレンスブルク
# 母
# 妊娠
# 一報
# 攻略
# 種馬
# テラトーマ
# プラノ
# フィヨルド
# ブリリアニア
# クリスチャンサン
# リレサン
# 礎
# 岩礁
# 水路
# 浅い
# 見つかる
# たとえば
# 淡水
# ルール
# 骨
# ビール
# 蜂蜜
# 酒
# ビョール
# 尾てい
# 度数
# フルーツ
# 裕福
# 困難
# メーザ
# ノストラム
# 枠組み
# 血球
# 赤
# ミシシッピ
# 運ぶ
# オハイオ
# 酸素
# 疑念
# ムード
# 奴隷
# ディートリッヒ
# 温帯
# 出来事
# 本社
# 分裂
# デンバー
# 黄緑
# 青み
# がかっ
# 種類
# 緑
# 穏やか
# アルジェリア
# テキサス
# ルーマニア
# 役職
# 速やか
# 診断
# 音波
# 介し
# 輸送
# 物品
# トン
# 超
# トゥルチャ
# 異なり
# 県
# 左岸
# ドナー
# オデッサ
# 待機
# 体内
# 見なさ
# 質
# タンパク
# 呼び
# マレ
# ついに
# シスコーカサス
# 交替
# 可決
# 方言
# 両方
# 観
# 仕掛け
# 爆弾
# コーサカス
# 本部
# 何者
# 子音
# トランスコーカシア
# チャペル
# カオス
# 起きる
# 降っ
# 水滴
# ヒルズボロ
# 吸収
# 気象
# 階程
# キャンベル
# 引きつけ
# 替え
# わたる
# 初代
# 粗末
# ルートヴィヒ
# 座
# エコノミスト
# ラスチスラフ
# 甥
# ラスティス
# 一致
# 派生
# レトリック
# 至る
# 置か
# 借用
# メアンキエリ
# 燃え上がる
# クヴェン
# 回っ
# 対処
# 制御
# 重力
# 愛す
# にぎわい
# 矮小
# 児童
# 形態
# ネーション
# サヘル
# 意見
# 好ましい
# まったく
# 飢饉
# 渡っ
# 利害
# ポジティブ
# 釣り
# 海産
# 食糧
# 上げ
# いじめ
# 地質
# ボノ
# 称し
# 公聴
# 返答
# リフト
# ぜいたく
# リング
# テクトニクス
# キリマンジャロ
# ケニア
# 峰
# 山々
# 囲ま
# 赤道
# 残骸
# 当てはまる
# 改善
# 広め
# バンツー
# 言説
# コンテンツ
# 信奉
# エンターテインメント
# 有能
# 応える
# インフラ
# コロラド
# 処置
# 眠れる
# 雷雨
# 風速
# 速い
# 気流
# 舞い上がり
# 落ちる
# 飛び交う
# ぶつかり
# 連鎖
# 肥満
# カイロ
# 煽動
# 対話
# ゲズィーラ
# 島内
# マクニーリー
# ネバダ
# ゲリー
# ずつ
# 観光
# 鉱業
# 振動
# 微
# 印刷
# 予算
# 下水
# 道
# ゴミ捨て
# 並
# 悪化
# 集約
# サリアンヌ
# アトキンソン
# イヤー
# リバー
# 幹部
# 砂
# 草木
# 現象
# 細かい
# 吹き飛ばさ
# いわゆる
# 上回っ
# 吹き
# 始める
# 注射
# パッド
# 吐き気
# 人脈
# 会う
# カウンセラー
# ライ
# エッセイ
# 海底
# 沿い
# 巡る
# 現し
# 姿
# ブルックス
# 航海
# 選ぶ
# 原稿
# メラニア
# さん
# 大衆
# 知れ
# 恭愍
# みな
# 当て
# ユーラシア
# 探す
# 食品
# アンティリャス
# 加工
# 電気
# 設備
# 処方
# 後半
# 足
# 踏み入れ
# カリブス
# 由来
# シー
# 海路
# ジ
# アンティレス
# 共通
# 疼痛
# 北側
# 南海
# パナマ
# 南側
# 癒し
# ウェブ
# 繁栄
# 盗ん
# 惨事
# カスタマー
# 達し
# 学問
# 表記
# ケイ酸
# 含量
# 粘性
# 到達
# 冷える
# 爆発
# リンゼイ
# 起こさ
# 変容
# 野生
# 開拓
# 東部
# メラネシア
# ケンタッキー
# インディアナ
# 携帯
# アドリア
# ゲイ
# 遅れ
# 夏季
# 腰痛
# 主日
# 合致
# コンドミニアム
# 柳
# 新規
# 飲料
# 灌漑
# レンタル
# ミラノ
# 上流
# アプリケーション
# ロジャース
# 超える
# キロワット
# 電力
# ローヌ
# イン
# ティチーノ
# ポー
# 農家
# 家具
# 大工
# ゴメリー
# 性的
# 暴力
# 烙印
# 押さ
# 群
# 北米
# ケベック
# 西
# 大西
# 火付け
# 晴らさ
# 遠隔
# 道路
# 免責
# 昼間
# 高温
# 氷点
# シップ
# 合計
# 数千
# 劣化
# 枯渇
# 素
# 栄養
# 洪水
# 干ばつ
# 不作
# 病気
# まん延
# 水質
# 嫌疑
# 脆弱
# 背信
# 詐欺
# 慣行
# 兆候
# 金融
# 悪
# 度合い
# 軽減
# 侵食
# 塩類
# 圧縮
# 読み上げ

# %%
#If the chinese version is desired, the code works as is for the obtention of the chinese CSV

c = Cihai()
if not c.unihan.is_bootstrapped:  # download and install Unihan to db
    c.unihan.bootstrap()
    

transTable="＝〜℃ⅲ＆１２２１６／α•／"

        
with open('./../pud_data/zho_pud.csv', newline='',encoding="utf-8") as csvfile:
    with open("./../pud_data/zho_pud_strokes.csv", 'w', encoding='UTF8', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(["","word","frequency","length"])
        
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='"')
        for row in spamreader:
            word=row[0]
            word = ''.join(i for i in word if i not in transTable)
            if len(word)>0:
                strokeSum=0
                for char in word:
                    query = c.unihan.lookup_char(char)
                    glyph = query.first()
                    if glyph!=None:
                        strokeSum+=int(glyph.kTotalStrokes[0])
                    else:
                        print(word)
                writer.writerow([word,word,row[2],strokeSum])
# Out:
# α
# •
# ／
